# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/Optimization/blob/main/RL_Traveling_Salesman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## RL Traveling Salesman
# In this notebook, we implement a reinforcement learning approach to the traveling salesman problem. It is based on Q-learning and structure2vec graph embeddings.

# %%
import numpy as np
import torch
import random
import math
from collections import namedtuple
import os
import time

from scipy.spatial import distance_matrix
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from scipy.signal import medfilt

""" Note: the code is not optimized for GPU
"""
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Create Graph Instances
# Below we implement a small method to generate random graph instances.

# %%
def get_graph_mat(n=10, size=1):
    """ Throws n nodes uniformly at random on a square, and build a (fully connected) graph.
        Returns the (N, 2) coordinates matrix, and the (N, N) matrix containing pairwise euclidean distances.
    """
    coords = size * np.random.uniform(size=(n,2))
    dist_mat = distance_matrix(coords, coords)
    return coords, dist_mat

def plot_graph(coords, mat):
    """ Utility function to plot the fully connected graph
    """
    n = len(coords)
    
    plt.scatter(coords[:,0], coords[:,1], s=[50 for _ in range(n)])
    for i in range(n):
        for j in range(n):
            if j < i:
                plt.plot([coords[i,0], coords[j,0]], [coords[i,1], coords[j,1]], 'b', alpha=0.7)

# %%
coords, W_np = get_graph_mat(n=10)
plot_graph(coords, W_np)

# %% [markdown]
# ## Define the state
# We now define the state tuple, containing a graph (given by a weights matrix W), the noode coordinates coords and the partial solution (list of visited nodes). We also define the function state2tens, which translates such tuples into tensors (partially loosing the sequence order information).

# %%
State = namedtuple('State', ('W', 'coords', 'partial_solution'))
  
def state2tens(state):
    """ Creates a Pytorch tensor representing the history of visited nodes, from a (single) state tuple.
        
        Returns a (Nx5) tensor, where for each node we store whether this node is in the sequence,
        whether it is first or last, and its (x,y) coordinates.
    """
    solution = set(state.partial_solution)
    sol_last_node = state.partial_solution[-1] if len(state.partial_solution) > 0 else -1
    sol_first_node = state.partial_solution[0] if len(state.partial_solution) > 0 else -1
    coords = state.coords
    nr_nodes = coords.shape[0]

    xv = [[(1 if i in solution else 0),
           (1 if i == sol_first_node else 0),
           (1 if i == sol_last_node else 0),
           coords[i,0],
           coords[i,1]
          ] for i in range(nr_nodes)]
    
    return torch.tensor(xv, dtype=torch.float32, requires_grad=False, device=device)

# %% [markdown]
# ## The Q-Function
# Below, we write the neural network that will parameterize the function Q(s, a).

# %%
class QNet(nn.Module):
    """ The neural net that will parameterize the function Q(s, a)
    
        The input is the state (containing the graph and visited nodes),
        and the output is a vector of size N containing Q(s, a) for each of the N actions a.
    """    
    
    def __init__(self, emb_dim, T=4):
        """ emb_dim: embedding dimension p
            T: number of iterations for the graph embedding
        """
        super(QNet, self).__init__()
        self.emb_dim = emb_dim
        self.T = T
        
        # We use 5 dimensions for representing the nodes' states:
        # * A binary variable indicating whether the node has been visited
        # * A binary variable indicating whether the node is the first of the visited sequence
        # * A binary variable indicating whether the node is the last of the visited sequence
        # * The (x, y) coordinates of the node.
        self.node_dim = 5
        
        # We can have an extra layer after theta_1 (for the sake of example to make the network deeper)
        nr_extra_layers_1 = 1
        
        # Build the learnable affine maps:
        self.theta1 = nn.Linear(self.node_dim, self.emb_dim, True)
        self.theta2 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta3 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta4 = nn.Linear(1, self.emb_dim, True)
        self.theta5 = nn.Linear(2*self.emb_dim, 1, True)
        self.theta6 = nn.Linear(self.emb_dim, self.emb_dim, True)
        self.theta7 = nn.Linear(self.emb_dim, self.emb_dim, True)
        
        self.theta1_extras = [nn.Linear(self.emb_dim, self.emb_dim, True) for _ in range(nr_extra_layers_1)]
        
    def forward(self, xv, Ws):
        # xv: The node features (batch_size, num_nodes, node_dim)
        # Ws: The graphs (batch_size, num_nodes, num_nodes)
        
        num_nodes = xv.shape[1]
        batch_size = xv.shape[0]
        
        # pre-compute 1-0 connection matrices masks (batch_size, num_nodes, num_nodes)
        conn_matrices = torch.where(Ws > 0, torch.ones_like(Ws), torch.zeros_like(Ws)).to(device)
        
        # Graph embedding
        # Note: we first compute s1 and s3 once, as they are not dependent on mu
        mu = torch.zeros(batch_size, num_nodes, self.emb_dim, device=device)
        s1 = self.theta1(xv)  # (batch_size, num_nodes, emb_dim)
        for layer in self.theta1_extras:
            s1 = layer(F.relu(s1))  # we apply the extra layer
        
        s3_1 = F.relu(self.theta4(Ws.unsqueeze(3)))  # (batch_size, nr_nodes, nr_nodes, emb_dim) - each "weigth" is a p-dim vector        
        s3_2 = torch.sum(s3_1, dim=1)  # (batch_size, nr_nodes, emb_dim) - the embedding for each node
        s3 = self.theta3(s3_2)  # (batch_size, nr_nodes, emb_dim)
        
        for t in range(self.T):
            s2 = self.theta2(conn_matrices.matmul(mu))    
            mu = F.relu(s1 + s2 + s3)
            
        """ prediction
        """
        # we repeat the global state (summed over nodes) for each node, 
        # in order to concatenate it to local states later
        global_state = self.theta6(torch.sum(mu, dim=1, keepdim=True).repeat(1, num_nodes, 1))
        
        local_action = self.theta7(mu)  # (batch_dim, nr_nodes, emb_dim)
            
        out = F.relu(torch.cat([global_state, local_action], dim=2))
        return self.theta5(out).squeeze(dim=2)

# %%
""" See what the model returns
"""
model = QNet(3, T=1).to(device)
coords, W_np = get_graph_mat(n=10)
W = torch.tensor(W_np, dtype=torch.float32, device=device)
xv = torch.rand((1, W.shape[0], 5)).to(device) # random node state
Ws = W.unsqueeze(0)

y = model(xv, Ws)
print('model output: {}'.format(y))
# Out:
# model output: tensor([[-0.6638, -0.6634, -0.6645, -0.6626, -0.6605, -0.6607, -0.6610, -0.6613,
#          -0.6648, -0.6629]], grad_fn=<SqueezeBackward1>)

# %% [markdown]
# ## A wrapper around the neural net
# Below, we define the class QFunction, which will act as a wrapper around the neural net QNet, and can manipulate TSP (partial) solutions and translate them to tensors.

# %%
class QFunction():
    def __init__(self, model, optimizer, lr_scheduler):
        self.model = model  # The actual QNet
        self.optimizer = optimizer
        self.lr_scheduler = lr_scheduler
        self.loss_fn = nn.MSELoss()
    
    def predict(self, state_tsr, W):
        # batch of 1 - only called at inference time
        with torch.no_grad():
            estimated_rewards = self.model(state_tsr.unsqueeze(0), W.unsqueeze(0))
        return estimated_rewards[0]
                
    def get_best_action(self, state_tsr, state):
        """ Computes the best (greedy) action to take from a given state
            Returns a tuple containing the ID of the next node and the corresponding estimated reward
        """
        W = state.W
        estimated_rewards = self.predict(state_tsr, W)  # size (nr_nodes,)
        sorted_reward_idx = estimated_rewards.argsort(descending=True)
        
        solution = state.partial_solution
        
        already_in = set(solution)
        for idx in sorted_reward_idx.tolist():
            if (len(solution) == 0 or W[solution[-1], idx] > 0) and idx not in already_in:
                return idx, estimated_rewards[idx].item()
        
    def batch_update(self, states_tsrs, Ws, actions, targets):
        """ Take a gradient step using the loss computed on a batch of (states, Ws, actions, targets)
        
            states_tsrs: list of (single) state tensors
            Ws: list of W tensors
            actions: list of actions taken
            targets: list of targets (resulting estimated rewards after taking the actions)
        """        
        Ws_tsr = torch.stack(Ws).to(device)
        xv = torch.stack(states_tsrs).to(device)
        self.optimizer.zero_grad()
        
        # the rewards estimated by Q for the given actions
        estimated_rewards = self.model(xv, Ws_tsr)[range(len(actions)), actions]
        
        loss = self.loss_fn(estimated_rewards, torch.tensor(targets, device=device))
        loss_val = loss.item()
        
        loss.backward()
        self.optimizer.step()        
        self.lr_scheduler.step()
        
        return loss_val

# %% [markdown]
# ## Define experiences & memory
# We'll now a tuple representing an experience, and the memory that contains such experiences. An experience is composed of a (state, action) tuple, and the corresponding "next state" and reward. The "next state" can be N step after the "state" in the case of N-step Q-learning. In experiences, we save states both in their tuple and tensor representations, in order to avoid computing these somewhat expensive translations after the experience has been stored.
#
# The Memory class implements a memory of limited size.

# %%
# Note: we store state tensors in experience to compute these tensors only once later on
Experience = namedtuple('Experience', ('state', 'state_tsr', 'action', 'reward', 'next_state', 'next_state_tsr'))

class Memory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
        self.nr_inserts = 0
        
    def remember(self, experience):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = experience
        self.position = (self.position + 1) % self.capacity
        self.nr_inserts += 1
        
    def sample_batch(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return min(self.nr_inserts, self.capacity)

# %% [markdown]
# ## Other useful things
# Below, we'll write a few more helper functions for computing solution length, deciding if a state is final and getting a next node at random from the graph.

# %%
def total_distance(solution, W):
    if len(solution) < 2:
        return 0  # there is no travel
    
    total_dist = 0
    for i in range(len(solution) - 1):
        total_dist += W[solution[i], solution[i+1]].item()
        
    # if this solution is "complete", go back to initial point
    if len(solution) == W.shape[0]:
        total_dist += W[solution[-1], solution[0]].item()

    return total_dist
        
def is_state_final(state):
    return len(set(state.partial_solution)) == state.W.shape[0]

def get_next_neighbor_random(state):
    solution, W = state.partial_solution, state.W
    
    if len(solution) == 0:
        return random.choice(range(W.shape[0]))
    already_in = set(solution)
    candidates = list(filter(lambda n: n.item() not in already_in, W[solution[-1]].nonzero()))
    if len(candidates) == 0:
        return None
    return random.choice(candidates).item()

# %% [markdown]
# ## Training Code
# #### Hyper-parameters

# %%
SEED = 1  # A seed for the random number generator

# Graph
NR_NODES = 10  # Number of nodes N
EMBEDDING_DIMENSIONS = 5  # Embedding dimension D
EMBEDDING_ITERATIONS_T = 1  # Number of embedding iterations T

# Learning
NR_EPISODES = 4001
MEMORY_CAPACITY = 10000
N_STEP_QL = 2  # Number of steps (n) in n-step Q-learning to wait before computing target reward estimate
BATCH_SIZE = 16

GAMMA = 0.9
INIT_LR = 5e-3
LR_DECAY_RATE = 1. - 2e-5  # learning rate decay

MIN_EPSILON = 0.1
EPSILON_DECAY_RATE = 6e-4  # epsilon decay

FOLDER_NAME = './models'  # where to checkpoint the best models

# %% [markdown]
# ## Model Initialization & checkpointing
# We will save our best models over the course of training - here we just define two functions for loading and checkpointing models

# %%
def init_model(fname=None):
    """ Create a new model. If fname is defined, load the model from the specified file.
    """
    Q_net = QNet(EMBEDDING_DIMENSIONS, T=EMBEDDING_ITERATIONS_T).to(device)
    optimizer = optim.Adam(Q_net.parameters(), lr=INIT_LR)
    lr_scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=LR_DECAY_RATE)
    
    if fname is not None:
        checkpoint = torch.load(fname)
        Q_net.load_state_dict(checkpoint['model'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
    
    Q_func = QFunction(Q_net, optimizer, lr_scheduler)
    return Q_func, Q_net, optimizer, lr_scheduler

def checkpoint_model(model, optimizer, lr_scheduler, loss, 
                     episode, avg_length):
    if not os.path.exists(FOLDER_NAME):
        os.makedirs(FOLDER_NAME)
    
    fname = os.path.join(FOLDER_NAME, 'ep_{}'.format(episode))
    fname += '_length_{}'.format(avg_length)
    fname += '.tar'
    
    torch.save({
        'episode': episode,
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'lr_scheduler': lr_scheduler.state_dict(),
        'loss': loss,
        'avg_length': avg_length
    }, fname)

# %% [markdown]
# ## Training Loop
# The code below is slightly more complex than the version appearing in the blog article. Notably, here in several places we maintain states represented both as tuples and tensors. We cache the tensor versions in order to avoid re-computing them many times. Also different from the article, the version below implements a version of n-step Q-learning, it checkpoints the best models (according to the median path length), and prints some information.

# %%
# seed everything for reproducible results first:
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# Create module, optimizer, LR scheduler, and Q-function
Q_func, Q_net, optimizer, lr_scheduler = init_model()

# Create memory
memory = Memory(MEMORY_CAPACITY)

# Storing metrics about training:
found_solutions = dict()  # episode --> (coords, W, solution)
losses = []
path_lengths = []

# keep track of median path length for model checkpointing
current_min_med_length = float('inf')

for episode in range(NR_EPISODES):
    # sample a new random graph
    coords, W_np = get_graph_mat(n=NR_NODES)
    W = torch.tensor(W_np, dtype=torch.float32, requires_grad=False, device=device)
    
    # current partial solution - a list of node index
    solution = [random.randint(0, NR_NODES-1)]
    
    # current state (tuple and tensor)
    current_state = State(partial_solution=solution, W=W, coords=coords)
    current_state_tsr = state2tens(current_state)
    
    # Keep track of some variables for insertion in replay memory:
    states = [current_state]
    states_tsrs = [current_state_tsr]  # we also keep the state tensors here (for efficiency)
    rewards = []
    actions = []
    
    # current value of epsilon
    epsilon = max(MIN_EPSILON, (1-EPSILON_DECAY_RATE)**episode)
    
    nr_explores = 0
    t = -1
    while not is_state_final(current_state):
        t += 1  # time step of this episode
        
        if epsilon >= random.random():
            # explore
            next_node = get_next_neighbor_random(current_state)
            nr_explores += 1
        else:
            # exploit
            next_node, est_reward = Q_func.get_best_action(current_state_tsr, current_state)
            if episode % 50 == 0:
                print('Ep {} | current sol: {} / next est reward: {}'.format(episode, solution, est_reward))
        
        next_solution = solution + [next_node]
        
        # reward observed for taking this step        
        reward = -(total_distance(next_solution, W) - total_distance(solution, W))
        
        next_state = State(partial_solution=next_solution, W=W, coords=coords)
        next_state_tsr = state2tens(next_state)
        
        # store rewards and states obtained along this episode:
        states.append(next_state)
        states_tsrs.append(next_state_tsr)
        rewards.append(reward)
        actions.append(next_node)
        
        # store our experience in memory, using n-step Q-learning:
        if len(solution) >= N_STEP_QL:
            memory.remember(Experience(state=states[-N_STEP_QL],
                                       state_tsr=states_tsrs[-N_STEP_QL],
                                       action=actions[-N_STEP_QL],
                                       reward=sum(rewards[-N_STEP_QL:]),
                                       next_state=next_state,
                                       next_state_tsr=next_state_tsr))
            
        if is_state_final(next_state):
            for n in range(1, N_STEP_QL):
                memory.remember(Experience(state=states[-n],
                                           state_tsr=states_tsrs[-n], 
                                           action=actions[-n], 
                                           reward=sum(rewards[-n:]), 
                                           next_state=next_state,
                                           next_state_tsr=next_state_tsr))
        
        # update state and current solution
        current_state = next_state
        current_state_tsr = next_state_tsr
        solution = next_solution
        
        # take a gradient step
        loss = None
        if len(memory) >= BATCH_SIZE and len(memory) >= 2000:
            experiences = memory.sample_batch(BATCH_SIZE)
            
            batch_states_tsrs = [e.state_tsr for e in experiences]
            batch_Ws = [e.state.W for e in experiences]
            batch_actions = [e.action for e in experiences]
            batch_targets = []
            
            for i, experience in enumerate(experiences):
                target = experience.reward
                if not is_state_final(experience.next_state):
                    _, best_reward = Q_func.get_best_action(experience.next_state_tsr, 
                                                            experience.next_state)
                    target += GAMMA * best_reward
                batch_targets.append(target)
                
            # print('batch targets: {}'.format(batch_targets))
            loss = Q_func.batch_update(batch_states_tsrs, batch_Ws, batch_actions, batch_targets)
            losses.append(loss)
            
            """ Save model when we reach a new low average path length
            """
            med_length = np.median(path_lengths[-100:])
            if med_length < current_min_med_length:
                current_min_med_length = med_length
                checkpoint_model(Q_net, optimizer, lr_scheduler, loss, episode, med_length)
                
    length = total_distance(solution, W)
    path_lengths.append(length)

    if episode % 10 == 0:
        print('Ep %d. Loss = %.3f / median length = %.3f / last = %.4f / epsilon = %.4f / lr = %.4f' % (
            episode, (-1 if loss is None else loss), np.median(path_lengths[-50:]), length, epsilon,
            Q_func.optimizer.param_groups[0]['lr']))
        found_solutions[episode] = (W.clone(), coords.copy(), [n for n in solution])
# Out:
# Ep 0. Loss = -1.000 / median length = 3.487 / last = 3.4873 / epsilon = 1.0000 / lr = 0.0050
# Ep 10. Loss = -1.000 / median length = 5.717 / last = 5.7169 / epsilon = 0.9940 / lr = 0.0050
# Ep 20. Loss = -1.000 / median length = 4.974 / last = 4.3185 / epsilon = 0.9881 / lr = 0.0050
# Ep 30. Loss = -1.000 / median length = 4.974 / last = 3.7427 / epsilon = 0.9822 / lr = 0.0050
# Ep 40. Loss = -1.000 / median length = 4.974 / last = 5.0773 / epsilon = 0.9763 / lr = 0.0050
# Ep 50 | current sol: [8, 5] / next est reward: 0.037708528339862823
# Ep 50 | current sol: [8, 5, 7, 4] / next est reward: 0.10300328582525253
# Ep 50. Loss = -1.000 / median length = 5.000 / last = 5.7980 / epsilon = 0.9704 / lr = 0.0050
# Ep 60. Loss = -1.000 / median length = 5.036 / last = 6.1192 / epsilon = 0.9646 / lr = 0.0050
# Ep 70. Loss = -1.000 / median length = 5.194 / last = 5.5106 / epsilon = 0.9589 / lr = 0.0050
# Ep 80. Loss = -1.000 / median length = 5.270 / last = 6.1859 / epsilon = 0.9531 / lr = 0.0050
# Ep 90. Loss = -1.000 / median length = 5.423 / last = 4.1432 / epsilon = 0.9474 / lr = 0.0050
# Ep 100 | current sol: [2, 5] / next est reward: 0.05864342302083969
# Ep 100. Loss = -1.000 / median length = 5.438 / last = 5.6594 / epsilon = 0.9417 / lr = 0.0050
# Ep 110. Loss = -1.000 / median length = 5.260 / last = 5.4424 / epsilon = 0.9361 / lr = 0.0050
# Ep 120. Loss = -1.000 / median length = 5.248 / last = 5.1267 / epsilon = 0.9305 / lr = 0.0050
# Ep 130. Loss = -1.000 / median length = 5.110 / last = 5.0265 / epsilon = 0.9249 / lr = 0.0050
# Ep 140. Loss = -1.000 / median length = 5.126 / last = 6.8115 / epsilon = 0.9194 / lr = 0.0050
# Ep 150 | current sol: [2, 9, 5, 1, 8, 4, 0] / next est reward: 0.17410334944725037
# Ep 150. Loss = -1.000 / median length = 5.092 / last = 6.6586 / epsilon = 0.9139 / lr = 0.0050
# Ep 160. Loss = -1.000 / median length = 5.175 / last = 4.8218 / epsilon = 0.9084 / lr = 0.0050
# Ep 170. Loss = -1.000 / median length = 5.267 / last = 6.2621 / epsilon = 0.9030 / lr = 0.0050
# Ep 180. Loss = -1.000 / median length = 5.322 / last = 4.9805 / epsilon = 0.8976 / lr = 0.0050
# Ep 190. Loss = -1.000 / median length = 5.322 / last = 5.8369 / epsilon = 0.8922 / lr = 0.0050
# Ep 200 | current sol: [0, 8, 7, 6, 4, 2, 1, 3] / next est reward: 0.26362866163253784
# Ep 200. Loss = -1.000 / median length = 5.386 / last = 4.1729 / epsilon = 0.8869 / lr = 0.0050
# Ep 210. Loss = -1.000 / median length = 5.353 / last = 5.3736 / epsilon = 0.8816 / lr = 0.0050
# Ep 220. Loss = -1.000 / median length = 5.373 / last = 5.4645 / epsilon = 0.8763 / lr = 0.0050
# Ep 230. Loss = 1.530 / median length = 5.387 / last = 5.7456 / epsilon = 0.8711 / lr = 0.0050
# Ep 240. Loss = 0.307 / median length = 5.249 / last = 4.4279 / epsilon = 0.8659 / lr = 0.0050
# Ep 250 | current sol: [3, 7] / next est reward: -6.310580253601074
# Ep 250. Loss = 0.102 / median length = 5.010 / last = 5.4373 / epsilon = 0.8607 / lr = 0.0050
# Ep 260. Loss = 0.145 / median length = 5.010 / last = 5.7680 / epsilon = 0.8555 / lr = 0.0050
# Ep 270. Loss = 0.121 / median length = 4.907 / last = 4.4324 / epsilon = 0.8504 / lr = 0.0050
# Ep 280. Loss = 0.234 / median length = 4.873 / last = 4.2769 / epsilon = 0.8453 / lr = 0.0049
# Ep 290. Loss = 0.107 / median length = 4.938 / last = 6.0861 / epsilon = 0.8403 / lr = 0.0049
# Ep 300. Loss = 0.220 / median length = 5.006 / last = 5.0578 / epsilon = 0.8352 / lr = 0.0049
# Ep 310. Loss = 0.124 / median length = 5.015 / last = 7.2335 / epsilon = 0.8302 / lr = 0.0049
# Ep 320. Loss = 0.089 / median length = 5.149 / last = 5.2851 / epsilon = 0.8253 / lr = 0.0049
# Ep 330. Loss = 0.521 / median length = 5.211 / last = 4.4904 / epsilon = 0.8203 / lr = 0.0049
# Ep 340. Loss = 0.398 / median length = 5.077 / last = 4.5899 / epsilon = 0.8154 / lr = 0.0049
# Ep 350 | current sol: [4, 3, 0, 1] / next est reward: -7.446508884429932
# Ep 350 | current sol: [4, 3, 0, 1, 9, 7, 5] / next est reward: -4.481555938720703
# Ep 350. Loss = 0.136 / median length = 5.160 / last = 4.4163 / epsilon = 0.8105 / lr = 0.0049
# Ep 360. Loss = 0.214 / median length = 5.014 / last = 4.2053 / epsilon = 0.8057 / lr = 0.0049
# Ep 370. Loss = 0.153 / median length = 4.891 / last = 4.1855 / epsilon = 0.8009 / lr = 0.0049
# Ep 380. Loss = 0.171 / median length = 4.945 / last = 4.5907 / epsilon = 0.7961 / lr = 0.0049
# Ep 390. Loss = 0.236 / median length = 4.964 / last = 5.0496 / epsilon = 0.7913 / lr = 0.0049
# Ep 400 | current sol: [1, 3] / next est reward: -9.130133628845215
# Ep 400 | current sol: [1, 3, 5, 8, 9, 4, 6, 2, 7] / next est reward: -2.49721360206604
# Ep 400. Loss = 0.086 / median length = 5.048 / last = 4.3465 / epsilon = 0.7866 / lr = 0.0048
# Ep 410. Loss = 0.076 / median length = 5.006 / last = 4.9777 / epsilon = 0.7819 / lr = 0.0048
# Ep 420. Loss = 0.140 / median length = 5.042 / last = 6.0914 / epsilon = 0.7772 / lr = 0.0048
# Ep 430. Loss = 0.287 / median length = 5.188 / last = 5.1669 / epsilon = 0.7725 / lr = 0.0048
# Ep 440. Loss = 0.323 / median length = 5.183 / last = 4.5960 / epsilon = 0.7679 / lr = 0.0048
# Ep 450 | current sol: [1, 5, 3] / next est reward: -9.280451774597168
# Ep 450 | current sol: [1, 5, 3, 0] / next est reward: -8.221207618713379
# Ep 450 | current sol: [1, 5, 3, 0, 4] / next est reward: -7.271495819091797
# Ep 450 | current sol: [1, 5, 3, 0, 4, 9, 7] / next est reward: -5.708123207092285
# Ep 450 | current sol: [1, 5, 3, 0, 4, 9, 7, 2] / next est reward: -4.675012588500977
# Ep 450. Loss = 0.164 / median length = 5.163 / last = 4.7102 / epsilon = 0.7633 / lr = 0.0048
# Ep 460. Loss = 0.152 / median length = 5.184 / last = 4.6909 / epsilon = 0.7588 / lr = 0.0048
# Ep 470. Loss = 0.169 / median length = 5.129 / last = 5.1002 / epsilon = 0.7542 / lr = 0.0048
# Ep 480. Loss = 0.269 / median length = 4.971 / last = 3.8314 / epsilon = 0.7497 / lr = 0.0048
# Ep 490. Loss = 0.340 / median length = 5.038 / last = 3.5654 / epsilon = 0.7452 / lr = 0.0048
# Ep 500 | current sol: [8, 4, 9] / next est reward: -8.52527141571045
# Ep 500 | current sol: [8, 4, 9, 5] / next est reward: -7.692477226257324
# Ep 500 | current sol: [8, 4, 9, 5, 7] / next est reward: -6.785966873168945
# Ep 500 | current sol: [8, 4, 9, 5, 7, 0] / next est reward: -5.9439496994018555
# Ep 500. Loss = 0.199 / median length = 4.886 / last = 5.7910 / epsilon = 0.7408 / lr = 0.0048
# Ep 510. Loss = 0.321 / median length = 4.902 / last = 5.7822 / epsilon = 0.7363 / lr = 0.0047
# Ep 520. Loss = 0.227 / median length = 4.902 / last = 5.2320 / epsilon = 0.7319 / lr = 0.0047
# Ep 530. Loss = 0.163 / median length = 4.842 / last = 4.2919 / epsilon = 0.7275 / lr = 0.0047
# Ep 540. Loss = 0.128 / median length = 4.889 / last = 5.4303 / epsilon = 0.7232 / lr = 0.0047
# Ep 550 | current sol: [1, 5] / next est reward: -10.219427108764648
# Ep 550 | current sol: [1, 5, 3, 6, 0, 7, 4, 9, 2] / next est reward: -2.7092232704162598
# Ep 550. Loss = 0.158 / median length = 4.849 / last = 6.3826 / epsilon = 0.7189 / lr = 0.0047
# Ep 560. Loss = 0.344 / median length = 4.944 / last = 4.5558 / epsilon = 0.7146 / lr = 0.0047
# Ep 570. Loss = 0.298 / median length = 4.827 / last = 4.4302 / epsilon = 0.7103 / lr = 0.0047
# Ep 580. Loss = 0.370 / median length = 4.827 / last = 4.7313 / epsilon = 0.7060 / lr = 0.0047
# Ep 590. Loss = 0.122 / median length = 4.943 / last = 5.1256 / epsilon = 0.7018 / lr = 0.0047
# Ep 600 | current sol: [1, 0, 8, 2, 9] / next est reward: -7.142868995666504
# Ep 600 | current sol: [1, 0, 8, 2, 9, 3, 5] / next est reward: -4.898172378540039
# Ep 600. Loss = 0.175 / median length = 5.048 / last = 5.6196 / epsilon = 0.6976 / lr = 0.0047
# Ep 610. Loss = 0.208 / median length = 5.083 / last = 4.9909 / epsilon = 0.6934 / lr = 0.0047
# Ep 620. Loss = 0.183 / median length = 5.133 / last = 4.5665 / epsilon = 0.6893 / lr = 0.0047
# Ep 630. Loss = 0.255 / median length = 5.191 / last = 3.4866 / epsilon = 0.6852 / lr = 0.0046
# Ep 640. Loss = 0.383 / median length = 5.245 / last = 4.8984 / epsilon = 0.6811 / lr = 0.0046
# Ep 650 | current sol: [5, 2, 4, 6, 1] / next est reward: -6.444371700286865
# Ep 650 | current sol: [5, 2, 4, 6, 1, 0] / next est reward: -5.6689043045043945
# Ep 650 | current sol: [5, 2, 4, 6, 1, 0, 8] / next est reward: -5.174311637878418
# Ep 650. Loss = 0.262 / median length = 5.229 / last = 4.3830 / epsilon = 0.6770 / lr = 0.0046
# Ep 660. Loss = 0.249 / median length = 5.213 / last = 5.8532 / epsilon = 0.6729 / lr = 0.0046
# Ep 670. Loss = 0.145 / median length = 5.103 / last = 6.2493 / epsilon = 0.6689 / lr = 0.0046
# Ep 680. Loss = 0.145 / median length = 5.011 / last = 5.8318 / epsilon = 0.6649 / lr = 0.0046
# Ep 690. Loss = 0.221 / median length = 4.948 / last = 5.6095 / epsilon = 0.6609 / lr = 0.0046
# Ep 700 | current sol: [3, 8, 9, 6, 0, 5, 7] / next est reward: -3.768108606338501
# Ep 700. Loss = 0.091 / median length = 5.011 / last = 3.6804 / epsilon = 0.6570 / lr = 0.0046
# Ep 710. Loss = 0.205 / median length = 4.971 / last = 3.5965 / epsilon = 0.6530 / lr = 0.0046
# Ep 720. Loss = 0.204 / median length = 4.990 / last = 4.2336 / epsilon = 0.6491 / lr = 0.0046
# Ep 730. Loss = 0.254 / median length = 5.076 / last = 5.2155 / epsilon = 0.6452 / lr = 0.0046
# Ep 740. Loss = 0.139 / median length = 5.213 / last = 5.8797 / epsilon = 0.6414 / lr = 0.0046
# Ep 750 | current sol: [3, 5] / next est reward: -8.34303092956543
# Ep 750 | current sol: [3, 5, 6, 7] / next est reward: -6.476346015930176
# Ep 750 | current sol: [3, 5, 6, 7, 4, 2] / next est reward: -4.826584339141846
# Ep 750 | current sol: [3, 5, 6, 7, 4, 2, 8] / next est reward: -4.1666412353515625
# Ep 750. Loss = 0.158 / median length = 5.123 / last = 4.1507 / epsilon = 0.6375 / lr = 0.0045
# Ep 760. Loss = 0.156 / median length = 5.213 / last = 4.8043 / epsilon = 0.6337 / lr = 0.0045
# Ep 770. Loss = 0.137 / median length = 5.219 / last = 4.4968 / epsilon = 0.6299 / lr = 0.0045
# Ep 780. Loss = 0.201 / median length = 5.252 / last = 5.2526 / epsilon = 0.6262 / lr = 0.0045
# Ep 790. Loss = 0.119 / median length = 5.169 / last = 5.1013 / epsilon = 0.6224 / lr = 0.0045
# Ep 800 | current sol: [3, 8, 1] / next est reward: -8.489644050598145
# Ep 800 | current sol: [3, 8, 1, 2, 7, 9] / next est reward: -6.065667152404785
# Ep 800. Loss = 0.316 / median length = 5.254 / last = 6.0307 / epsilon = 0.6187 / lr = 0.0045
# Ep 810. Loss = 0.222 / median length = 5.254 / last = 6.2894 / epsilon = 0.6150 / lr = 0.0045
# Ep 820. Loss = 0.238 / median length = 5.254 / last = 6.6956 / epsilon = 0.6113 / lr = 0.0045
# Ep 830. Loss = 0.175 / median length = 5.197 / last = 5.3559 / epsilon = 0.6077 / lr = 0.0045
# Ep 840. Loss = 0.068 / median length = 5.155 / last = 6.3520 / epsilon = 0.6040 / lr = 0.0045
# Ep 850 | current sol: [1, 8] / next est reward: -8.802329063415527
# Ep 850 | current sol: [1, 8, 6, 0] / next est reward: -7.388857364654541
# Ep 850 | current sol: [1, 8, 6, 0, 4, 2, 3] / next est reward: -4.9745259284973145
# Ep 850 | current sol: [1, 8, 6, 0, 4, 2, 3, 9] / next est reward: -3.926575183868408
# Ep 850. Loss = 0.258 / median length = 5.114 / last = 5.9132 / epsilon = 0.6004 / lr = 0.0045
# Ep 860. Loss = 0.211 / median length = 5.170 / last = 4.7639 / epsilon = 0.5968 / lr = 0.0045
# Ep 870. Loss = 0.158 / median length = 5.136 / last = 4.7188 / epsilon = 0.5932 / lr = 0.0044
# Ep 880. Loss = 0.213 / median length = 5.248 / last = 6.2741 / epsilon = 0.5897 / lr = 0.0044
# Ep 890. Loss = 0.219 / median length = 5.281 / last = 5.5964 / epsilon = 0.5862 / lr = 0.0044
# Ep 900 | current sol: [7, 3] / next est reward: -8.748653411865234
# Ep 900 | current sol: [7, 3, 5] / next est reward: -7.927249908447266
# Ep 900 | current sol: [7, 3, 5, 2, 0, 4, 6] / next est reward: -4.704596042633057
# Ep 900 | current sol: [7, 3, 5, 2, 0, 4, 6, 1] / next est reward: -4.151432037353516
# Ep 900. Loss = 0.110 / median length = 5.281 / last = 4.7225 / epsilon = 0.5827 / lr = 0.0044
# Ep 910. Loss = 0.136 / median length = 4.908 / last = 4.8123 / epsilon = 0.5792 / lr = 0.0044
# Ep 920. Loss = 0.203 / median length = 4.717 / last = 3.0978 / epsilon = 0.5757 / lr = 0.0044
# Ep 930. Loss = 0.180 / median length = 4.704 / last = 6.3661 / epsilon = 0.5723 / lr = 0.0044
# Ep 940. Loss = 0.182 / median length = 4.838 / last = 5.9384 / epsilon = 0.5688 / lr = 0.0044
# Ep 950 | current sol: [8, 7, 5, 6] / next est reward: -6.86644172668457
# Ep 950 | current sol: [8, 7, 5, 6, 0] / next est reward: -6.3643951416015625
# Ep 950 | current sol: [8, 7, 5, 6, 0, 9, 3] / next est reward: -4.723426818847656
# Ep 950 | current sol: [8, 7, 5, 6, 0, 9, 3, 4] / next est reward: -4.025130748748779
# Ep 950 | current sol: [8, 7, 5, 6, 0, 9, 3, 4, 1] / next est reward: -3.0489413738250732
# Ep 950. Loss = 0.120 / median length = 4.810 / last = 5.0287 / epsilon = 0.5654 / lr = 0.0044
# Ep 960. Loss = 0.160 / median length = 4.729 / last = 4.3345 / epsilon = 0.5620 / lr = 0.0044
# Ep 970. Loss = 0.566 / median length = 4.845 / last = 4.7390 / epsilon = 0.5587 / lr = 0.0044
# Ep 980. Loss = 0.209 / median length = 5.007 / last = 5.2532 / epsilon = 0.5553 / lr = 0.0044
# Ep 990. Loss = 0.106 / median length = 4.784 / last = 5.4469 / epsilon = 0.5520 / lr = 0.0044
# Ep 1000 | current sol: [9] / next est reward: -8.99930477142334
# Ep 1000 | current sol: [9, 6, 5, 2] / next est reward: -6.287553310394287
# Ep 1000 | current sol: [9, 6, 5, 2, 7] / next est reward: -5.522549152374268
# Ep 1000 | current sol: [9, 6, 5, 2, 7, 3] / next est reward: -4.840359687805176
# Ep 1000. Loss = 0.105 / median length = 4.784 / last = 5.4143 / epsilon = 0.5487 / lr = 0.0043
# Ep 1010. Loss = 0.146 / median length = 4.798 / last = 4.8577 / epsilon = 0.5454 / lr = 0.0043
# Ep 1020. Loss = 0.193 / median length = 4.784 / last = 4.1803 / epsilon = 0.5422 / lr = 0.0043
# Ep 1030. Loss = 0.101 / median length = 4.770 / last = 5.3348 / epsilon = 0.5389 / lr = 0.0043
# Ep 1040. Loss = 0.172 / median length = 4.945 / last = 6.2168 / epsilon = 0.5357 / lr = 0.0043
# Ep 1050 | current sol: [5, 0] / next est reward: -7.7474260330200195
# Ep 1050 | current sol: [5, 0, 1, 9] / next est reward: -6.185981273651123
# Ep 1050 | current sol: [5, 0, 1, 9, 6] / next est reward: -5.395798683166504
# Ep 1050 | current sol: [5, 0, 1, 9, 6, 8, 2, 3] / next est reward: -3.228048801422119
# Ep 1050. Loss = 0.132 / median length = 4.968 / last = 4.9746 / epsilon = 0.5325 / lr = 0.0043
# Ep 1060. Loss = 0.113 / median length = 5.075 / last = 3.6949 / epsilon = 0.5293 / lr = 0.0043
# Ep 1070. Loss = 0.107 / median length = 5.097 / last = 4.4473 / epsilon = 0.5261 / lr = 0.0043
# Ep 1080. Loss = 0.065 / median length = 5.097 / last = 4.7869 / epsilon = 0.5230 / lr = 0.0043
# Ep 1090. Loss = 0.068 / median length = 5.122 / last = 3.6596 / epsilon = 0.5199 / lr = 0.0043
# Ep 1100 | current sol: [9, 6, 4] / next est reward: -7.882421493530273
# Ep 1100 | current sol: [9, 6, 4, 2, 3] / next est reward: -6.442577362060547
# Ep 1100 | current sol: [9, 6, 4, 2, 3, 0] / next est reward: -5.608741760253906
# Ep 1100 | current sol: [9, 6, 4, 2, 3, 0, 5] / next est reward: -4.965238094329834
# Ep 1100. Loss = 0.244 / median length = 5.211 / last = 4.3389 / epsilon = 0.5167 / lr = 0.0043
# Ep 1110. Loss = 0.165 / median length = 5.153 / last = 4.4828 / epsilon = 0.5137 / lr = 0.0043
# Ep 1120. Loss = 0.145 / median length = 5.001 / last = 4.1283 / epsilon = 0.5106 / lr = 0.0043
# Ep 1130. Loss = 0.286 / median length = 4.933 / last = 5.2534 / epsilon = 0.5075 / lr = 0.0042
# Ep 1140. Loss = 0.221 / median length = 4.780 / last = 4.8588 / epsilon = 0.5045 / lr = 0.0042
# Ep 1150 | current sol: [2] / next est reward: -8.797703742980957
# Ep 1150 | current sol: [2, 3] / next est reward: -7.79243803024292
# Ep 1150 | current sol: [2, 3, 4] / next est reward: -7.001489162445068
# Ep 1150 | current sol: [2, 3, 4, 6] / next est reward: -6.162793159484863
# Ep 1150. Loss = 0.149 / median length = 4.810 / last = 5.1378 / epsilon = 0.5015 / lr = 0.0042
# Ep 1160. Loss = 0.138 / median length = 4.810 / last = 4.6575 / epsilon = 0.4985 / lr = 0.0042
# Ep 1170. Loss = 0.206 / median length = 4.777 / last = 3.9275 / epsilon = 0.4955 / lr = 0.0042
# Ep 1180. Loss = 0.270 / median length = 4.981 / last = 5.5556 / epsilon = 0.4925 / lr = 0.0042
# Ep 1190. Loss = 0.225 / median length = 5.044 / last = 5.8920 / epsilon = 0.4896 / lr = 0.0042
# Ep 1200 | current sol: [2, 8] / next est reward: -8.384628295898438
# Ep 1200 | current sol: [2, 8, 4] / next est reward: -7.781054496765137
# Ep 1200 | current sol: [2, 8, 4, 1] / next est reward: -7.088168144226074
# Ep 1200 | current sol: [2, 8, 4, 1, 0] / next est reward: -6.447885513305664
# Ep 1200 | current sol: [2, 8, 4, 1, 0, 6] / next est reward: -5.990532875061035
# Ep 1200 | current sol: [2, 8, 4, 1, 0, 6, 5] / next est reward: -5.300278663635254
# Ep 1200 | current sol: [2, 8, 4, 1, 0, 6, 5, 3, 9] / next est reward: -3.534933567047119
# Ep 1200. Loss = 0.215 / median length = 4.993 / last = 4.1885 / epsilon = 0.4866 / lr = 0.0042
# Ep 1210. Loss = 0.097 / median length = 4.993 / last = 6.8240 / epsilon = 0.4837 / lr = 0.0042
# Ep 1220. Loss = 0.148 / median length = 5.026 / last = 5.8110 / epsilon = 0.4808 / lr = 0.0042
# Ep 1230. Loss = 0.326 / median length = 4.953 / last = 5.7648 / epsilon = 0.4780 / lr = 0.0042
# Ep 1240. Loss = 0.250 / median length = 5.026 / last = 4.1487 / epsilon = 0.4751 / lr = 0.0042
# Ep 1250 | current sol: [7] / next est reward: -6.70924711227417
# Ep 1250 | current sol: [7, 9, 5, 2] / next est reward: -4.821701526641846
# Ep 1250 | current sol: [7, 9, 5, 2, 3] / next est reward: -4.474018573760986
# Ep 1250 | current sol: [7, 9, 5, 2, 3, 4] / next est reward: -4.0728254318237305
# Ep 1250 | current sol: [7, 9, 5, 2, 3, 4, 1, 6] / next est reward: -2.809093713760376
# Ep 1250 | current sol: [7, 9, 5, 2, 3, 4, 1, 6, 8] / next est reward: -2.633789300918579
# Ep 1250. Loss = 0.156 / median length = 5.022 / last = 4.8195 / epsilon = 0.4723 / lr = 0.0042
# Ep 1260. Loss = 0.282 / median length = 4.853 / last = 4.5610 / epsilon = 0.4694 / lr = 0.0041
# Ep 1270. Loss = 0.180 / median length = 5.139 / last = 5.4909 / epsilon = 0.4666 / lr = 0.0041
# Ep 1280. Loss = 0.274 / median length = 5.076 / last = 4.1170 / epsilon = 0.4638 / lr = 0.0041
# Ep 1290. Loss = 0.152 / median length = 5.076 / last = 3.7519 / epsilon = 0.4611 / lr = 0.0041
# Ep 1300 | current sol: [6, 5] / next est reward: -7.340975284576416
# Ep 1300 | current sol: [6, 5, 9] / next est reward: -6.73810338973999
# Ep 1300 | current sol: [6, 5, 9, 4, 0, 3] / next est reward: -4.876681327819824
# Ep 1300 | current sol: [6, 5, 9, 4, 0, 3, 1, 8, 7] / next est reward: -2.774388551712036
# Ep 1300. Loss = 0.257 / median length = 5.135 / last = 5.1897 / epsilon = 0.4583 / lr = 0.0041
# Ep 1310. Loss = 0.289 / median length = 5.222 / last = 4.3168 / epsilon = 0.4556 / lr = 0.0041
# Ep 1320. Loss = 0.125 / median length = 5.165 / last = 2.2267 / epsilon = 0.4528 / lr = 0.0041
# Ep 1330. Loss = 0.220 / median length = 5.165 / last = 4.5189 / epsilon = 0.4501 / lr = 0.0041
# Ep 1340. Loss = 0.277 / median length = 5.165 / last = 2.8026 / epsilon = 0.4474 / lr = 0.0041
# Ep 1350 | current sol: [7, 0] / next est reward: -8.14498233795166
# Ep 1350 | current sol: [7, 0, 4] / next est reward: -7.257290840148926
# Ep 1350 | current sol: [7, 0, 4, 9, 3] / next est reward: -6.045224189758301
# Ep 1350 | current sol: [7, 0, 4, 9, 3, 8, 6] / next est reward: -4.650483131408691
# Ep 1350 | current sol: [7, 0, 4, 9, 3, 8, 6, 2] / next est reward: -4.260188102722168
# Ep 1350 | current sol: [7, 0, 4, 9, 3, 8, 6, 2, 5] / next est reward: -3.314323902130127
# Ep 1350. Loss = 0.183 / median length = 4.981 / last = 6.1093 / epsilon = 0.4447 / lr = 0.0041
# Ep 1360. Loss = 0.265 / median length = 4.781 / last = 3.9938 / epsilon = 0.4421 / lr = 0.0041
# Ep 1370. Loss = 0.196 / median length = 5.104 / last = 6.1115 / epsilon = 0.4394 / lr = 0.0041
# Ep 1380. Loss = 0.256 / median length = 5.104 / last = 4.8320 / epsilon = 0.4368 / lr = 0.0041
# Ep 1390. Loss = 0.149 / median length = 5.021 / last = 5.4132 / epsilon = 0.4342 / lr = 0.0041
# Ep 1400 | current sol: [6] / next est reward: -8.339982032775879
# Ep 1400 | current sol: [6, 8, 0] / next est reward: -7.020832538604736
# Ep 1400 | current sol: [6, 8, 0, 1] / next est reward: -6.091023921966553
# Ep 1400 | current sol: [6, 8, 0, 1, 5, 7, 9, 2] / next est reward: -3.4734911918640137
# Ep 1400. Loss = 0.111 / median length = 5.156 / last = 5.5917 / epsilon = 0.4316 / lr = 0.0040
# Ep 1410. Loss = 0.246 / median length = 5.156 / last = 5.6066 / epsilon = 0.4290 / lr = 0.0040
# Ep 1420. Loss = 0.335 / median length = 5.004 / last = 4.2527 / epsilon = 0.4265 / lr = 0.0040
# Ep 1430. Loss = 0.389 / median length = 4.999 / last = 4.4839 / epsilon = 0.4239 / lr = 0.0040
# Ep 1440. Loss = 0.131 / median length = 5.039 / last = 4.3396 / epsilon = 0.4214 / lr = 0.0040
# Ep 1450 | current sol: [3] / next est reward: -8.326370239257812
# Ep 1450 | current sol: [3, 6] / next est reward: -7.636354446411133
# Ep 1450 | current sol: [3, 6, 7] / next est reward: -7.101940155029297
# Ep 1450 | current sol: [3, 6, 7, 8] / next est reward: -6.697139739990234
# Ep 1450 | current sol: [3, 6, 7, 8, 0, 4] / next est reward: -5.017256736755371
# Ep 1450 | current sol: [3, 6, 7, 8, 0, 4, 9, 5, 1] / next est reward: -2.792529821395874
# Ep 1450. Loss = 0.235 / median length = 4.878 / last = 4.8199 / epsilon = 0.4188 / lr = 0.0040
# Ep 1460. Loss = 0.181 / median length = 5.006 / last = 6.3377 / epsilon = 0.4163 / lr = 0.0040
# Ep 1470. Loss = 0.081 / median length = 5.060 / last = 4.1664 / epsilon = 0.4138 / lr = 0.0040
# Ep 1480. Loss = 0.094 / median length = 5.059 / last = 5.4631 / epsilon = 0.4114 / lr = 0.0040
# Ep 1490. Loss = 0.234 / median length = 5.055 / last = 5.0614 / epsilon = 0.4089 / lr = 0.0040
# Ep 1500 | current sol: [2, 4, 8] / next est reward: -6.621309757232666
# Ep 1500 | current sol: [2, 4, 8, 7] / next est reward: -6.100233554840088
# Ep 1500 | current sol: [2, 4, 8, 7, 9, 3, 1] / next est reward: -4.049594879150391
# Ep 1500 | current sol: [2, 4, 8, 7, 9, 3, 1, 0] / next est reward: -3.2484233379364014
# Ep 1500. Loss = 0.136 / median length = 5.070 / last = 5.6485 / epsilon = 0.4065 / lr = 0.0040
# Ep 1510. Loss = 0.142 / median length = 5.032 / last = 4.7649 / epsilon = 0.4040 / lr = 0.0040
# Ep 1520. Loss = 0.170 / median length = 4.949 / last = 4.3606 / epsilon = 0.4016 / lr = 0.0040
# Ep 1530. Loss = 0.221 / median length = 5.024 / last = 5.1608 / epsilon = 0.3992 / lr = 0.0040
# Ep 1540. Loss = 0.170 / median length = 5.024 / last = 5.7149 / epsilon = 0.3968 / lr = 0.0039
# Ep 1550 | current sol: [1] / next est reward: -7.019920349121094
# Ep 1550 | current sol: [1, 8] / next est reward: -6.441304683685303
# Ep 1550 | current sol: [1, 8, 4, 5, 7, 2, 9, 3, 0] / next est reward: -2.143602132797241
# Ep 1550. Loss = 0.140 / median length = 4.766 / last = 6.4313 / epsilon = 0.3944 / lr = 0.0039
# Ep 1560. Loss = 0.198 / median length = 4.722 / last = 5.5005 / epsilon = 0.3921 / lr = 0.0039
# Ep 1570. Loss = 0.148 / median length = 4.686 / last = 6.3659 / epsilon = 0.3897 / lr = 0.0039
# Ep 1580. Loss = 0.109 / median length = 4.762 / last = 4.6544 / epsilon = 0.3874 / lr = 0.0039
# Ep 1590. Loss = 0.102 / median length = 4.656 / last = 4.5514 / epsilon = 0.3851 / lr = 0.0039
# Ep 1600 | current sol: [6, 7, 8, 9, 2, 0, 1] / next est reward: -3.2550172805786133
# Ep 1600 | current sol: [6, 7, 8, 9, 2, 0, 1, 3] / next est reward: -2.769390344619751
# Ep 1600. Loss = 0.148 / median length = 4.957 / last = 4.3493 / epsilon = 0.3828 / lr = 0.0039
# Ep 1610. Loss = 0.139 / median length = 4.967 / last = 4.4899 / epsilon = 0.3805 / lr = 0.0039
# Ep 1620. Loss = 0.141 / median length = 4.982 / last = 4.2335 / epsilon = 0.3782 / lr = 0.0039
# Ep 1630. Loss = 0.096 / median length = 4.967 / last = 5.9390 / epsilon = 0.3760 / lr = 0.0039
# Ep 1640. Loss = 0.087 / median length = 5.079 / last = 5.3508 / epsilon = 0.3737 / lr = 0.0039
# Ep 1650 | current sol: [0, 7, 3] / next est reward: -7.137423038482666
# Ep 1650 | current sol: [0, 7, 3, 2] / next est reward: -6.398858070373535
# Ep 1650 | current sol: [0, 7, 3, 2, 1] / next est reward: -5.6660475730896
# Ep 1650 | current sol: [0, 7, 3, 2, 1, 6] / next est reward: -5.0378804206848145
# Ep 1650 | current sol: [0, 7, 3, 2, 1, 6, 5] / next est reward: -4.462191581726074
# Ep 1650 | current sol: [0, 7, 3, 2, 1, 6, 5, 8] / next est reward: -4.163671493530273
# Ep 1650. Loss = 0.252 / median length = 4.995 / last = 4.5878 / epsilon = 0.3715 / lr = 0.0039
# Ep 1660. Loss = 0.193 / median length = 5.184 / last = 6.0256 / epsilon = 0.3692 / lr = 0.0039
# Ep 1670. Loss = 0.043 / median length = 5.046 / last = 3.4591 / epsilon = 0.3670 / lr = 0.0039
# Ep 1680. Loss = 0.217 / median length = 4.986 / last = 5.3448 / epsilon = 0.3648 / lr = 0.0038
# Ep 1690. Loss = 0.131 / median length = 4.815 / last = 5.0539 / epsilon = 0.3627 / lr = 0.0038
# Ep 1700 | current sol: [2, 5] / next est reward: -4.948513984680176
# Ep 1700 | current sol: [2, 5, 9] / next est reward: -4.857245922088623
# Ep 1700 | current sol: [2, 5, 9, 1] / next est reward: -4.7536749839782715
# Ep 1700 | current sol: [2, 5, 9, 1, 6, 3] / next est reward: -4.439533710479736
# Ep 1700 | current sol: [2, 5, 9, 1, 6, 3, 4, 0, 7] / next est reward: -1.9569673538208008
# Ep 1700. Loss = 0.283 / median length = 4.978 / last = 3.5229 / epsilon = 0.3605 / lr = 0.0038
# Ep 1710. Loss = 0.066 / median length = 4.939 / last = 4.9379 / epsilon = 0.3583 / lr = 0.0038
# Ep 1720. Loss = 0.090 / median length = 4.978 / last = 4.5542 / epsilon = 0.3562 / lr = 0.0038
# Ep 1730. Loss = 0.057 / median length = 4.956 / last = 4.6310 / epsilon = 0.3541 / lr = 0.0038
# Ep 1740. Loss = 0.110 / median length = 4.955 / last = 5.3957 / epsilon = 0.3519 / lr = 0.0038
# Ep 1750 | current sol: [8] / next est reward: -6.1373090744018555
# Ep 1750 | current sol: [8, 9, 1, 3, 7, 2] / next est reward: -4.367238998413086
# Ep 1750 | current sol: [8, 9, 1, 3, 7, 2, 6, 5] / next est reward: -2.923323392868042
# Ep 1750 | current sol: [8, 9, 1, 3, 7, 2, 6, 5, 4] / next est reward: -2.462104558944702
# Ep 1750. Loss = 0.112 / median length = 4.914 / last = 6.1128 / epsilon = 0.3498 / lr = 0.0038
# Ep 1760. Loss = 0.075 / median length = 4.869 / last = 4.0426 / epsilon = 0.3477 / lr = 0.0038
# Ep 1770. Loss = 0.103 / median length = 4.866 / last = 4.4446 / epsilon = 0.3457 / lr = 0.0038
# Ep 1780. Loss = 0.088 / median length = 4.869 / last = 5.4241 / epsilon = 0.3436 / lr = 0.0038
# Ep 1790. Loss = 0.092 / median length = 4.891 / last = 5.3874 / epsilon = 0.3415 / lr = 0.0038
# Ep 1800 | current sol: [7, 0, 2] / next est reward: -5.404711723327637
# Ep 1800 | current sol: [7, 0, 2, 6] / next est reward: -5.13550329208374
# Ep 1800 | current sol: [7, 0, 2, 6, 9] / next est reward: -4.840818405151367
# Ep 1800 | current sol: [7, 0, 2, 6, 9, 8] / next est reward: -4.538210868835449
# Ep 1800 | current sol: [7, 0, 2, 6, 9, 8, 5, 3] / next est reward: -3.001335382461548
# Ep 1800. Loss = 0.126 / median length = 4.808 / last = 4.2191 / epsilon = 0.3395 / lr = 0.0038
# Ep 1810. Loss = 0.056 / median length = 4.770 / last = 5.1931 / epsilon = 0.3375 / lr = 0.0038
# Ep 1820. Loss = 0.027 / median length = 4.737 / last = 3.6814 / epsilon = 0.3354 / lr = 0.0037
# Ep 1830. Loss = 0.084 / median length = 4.817 / last = 4.9231 / epsilon = 0.3334 / lr = 0.0037
# Ep 1840. Loss = 0.136 / median length = 4.894 / last = 5.7814 / epsilon = 0.3314 / lr = 0.0037
# Ep 1850 | current sol: [5, 1, 9] / next est reward: -5.5878496170043945
# Ep 1850 | current sol: [5, 1, 9, 4] / next est reward: -5.413043975830078
# Ep 1850 | current sol: [5, 1, 9, 4, 2] / next est reward: -5.449253082275391
# Ep 1850 | current sol: [5, 1, 9, 4, 2, 8] / next est reward: -5.203053951263428
# Ep 1850 | current sol: [5, 1, 9, 4, 2, 8, 7] / next est reward: -4.624208450317383
# Ep 1850 | current sol: [5, 1, 9, 4, 2, 8, 7, 3] / next est reward: -3.7748167514801025
# Ep 1850. Loss = 0.165 / median length = 5.052 / last = 4.9833 / epsilon = 0.3294 / lr = 0.0037
# Ep 1860. Loss = 0.054 / median length = 5.154 / last = 5.2491 / epsilon = 0.3275 / lr = 0.0037
# Ep 1870. Loss = 0.077 / median length = 5.117 / last = 5.1200 / epsilon = 0.3255 / lr = 0.0037
# Ep 1880. Loss = 0.184 / median length = 5.139 / last = 5.5646 / epsilon = 0.3236 / lr = 0.0037
# Ep 1890. Loss = 0.116 / median length = 5.048 / last = 3.9495 / epsilon = 0.3216 / lr = 0.0037
# Ep 1900 | current sol: [9, 2, 7, 1] / next est reward: -3.7036924362182617
# Ep 1900 | current sol: [9, 2, 7, 1, 6] / next est reward: -3.276939868927002
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 5] / next est reward: -2.9603559970855713
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 5, 3] / next est reward: -2.6805057525634766
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 5, 3, 4] / next est reward: -2.3179945945739746
# Ep 1900 | current sol: [9, 2, 7, 1, 6, 5, 3, 4, 8] / next est reward: -1.9384713172912598
# Ep 1900. Loss = 0.132 / median length = 4.877 / last = 4.2672 / epsilon = 0.3197 / lr = 0.0037
# Ep 1910. Loss = 0.079 / median length = 4.679 / last = 4.5547 / epsilon = 0.3178 / lr = 0.0037
# Ep 1920. Loss = 0.045 / median length = 4.760 / last = 4.7253 / epsilon = 0.3159 / lr = 0.0037
# Ep 1930. Loss = 0.103 / median length = 4.565 / last = 3.8149 / epsilon = 0.3140 / lr = 0.0037
# Ep 1940. Loss = 0.204 / median length = 4.526 / last = 4.8995 / epsilon = 0.3121 / lr = 0.0037
# Ep 1950 | current sol: [6] / next est reward: -6.608521938323975
# Ep 1950 | current sol: [6, 5, 0, 2, 4] / next est reward: -5.183912754058838
# Ep 1950 | current sol: [6, 5, 0, 2, 4, 8, 3] / next est reward: -3.8625893592834473
# Ep 1950 | current sol: [6, 5, 0, 2, 4, 8, 3, 7] / next est reward: -2.6590871810913086
# Ep 1950. Loss = 0.081 / median length = 4.579 / last = 7.0433 / epsilon = 0.3103 / lr = 0.0037
# Ep 1960. Loss = 0.062 / median length = 4.756 / last = 5.3420 / epsilon = 0.3084 / lr = 0.0037
# Ep 1970. Loss = 0.227 / median length = 4.795 / last = 5.4388 / epsilon = 0.3066 / lr = 0.0036
# Ep 1980. Loss = 0.099 / median length = 4.828 / last = 3.8588 / epsilon = 0.3047 / lr = 0.0036
# Ep 1990. Loss = 0.218 / median length = 4.867 / last = 4.8527 / epsilon = 0.3029 / lr = 0.0036
# Ep 2000 | current sol: [0] / next est reward: -6.095064640045166
# Ep 2000 | current sol: [0, 8] / next est reward: -5.786619663238525
# Ep 2000 | current sol: [0, 8, 4] / next est reward: -5.513899326324463
# Ep 2000 | current sol: [0, 8, 4, 1, 9] / next est reward: -4.689046382904053
# Ep 2000 | current sol: [0, 8, 4, 1, 9, 2] / next est reward: -3.996952533721924
# Ep 2000 | current sol: [0, 8, 4, 1, 9, 2, 5, 7, 6] / next est reward: -1.6068432331085205
# Ep 2000. Loss = 0.107 / median length = 4.822 / last = 4.9178 / epsilon = 0.3011 / lr = 0.0036
# Ep 2010. Loss = 0.180 / median length = 4.735 / last = 3.8276 / epsilon = 0.2993 / lr = 0.0036
# Ep 2020. Loss = 0.066 / median length = 4.672 / last = 2.7051 / epsilon = 0.2975 / lr = 0.0036
# Ep 2030. Loss = 0.132 / median length = 4.726 / last = 5.2874 / epsilon = 0.2957 / lr = 0.0036
# Ep 2040. Loss = 0.118 / median length = 4.693 / last = 4.7496 / epsilon = 0.2939 / lr = 0.0036
# Ep 2050 | current sol: [8] / next est reward: -7.029353618621826
# Ep 2050 | current sol: [8, 3] / next est reward: -6.749976634979248
# Ep 2050 | current sol: [8, 3, 6, 0] / next est reward: -6.053601264953613
# Ep 2050 | current sol: [8, 3, 6, 0, 1] / next est reward: -5.706625938415527
# Ep 2050 | current sol: [8, 3, 6, 0, 1, 7] / next est reward: -5.2933244705200195
# Ep 2050 | current sol: [8, 3, 6, 0, 1, 7, 2] / next est reward: -4.464254379272461
# Ep 2050 | current sol: [8, 3, 6, 0, 1, 7, 2, 5] / next est reward: -3.500091075897217
# Ep 2050 | current sol: [8, 3, 6, 0, 1, 7, 2, 5, 4] / next est reward: -2.5521950721740723
# Ep 2050. Loss = 0.087 / median length = 4.773 / last = 5.6976 / epsilon = 0.2922 / lr = 0.0036
# Ep 2060. Loss = 0.119 / median length = 4.763 / last = 5.9773 / epsilon = 0.2904 / lr = 0.0036
# Ep 2070. Loss = 0.114 / median length = 4.818 / last = 6.2075 / epsilon = 0.2887 / lr = 0.0036
# Ep 2080. Loss = 0.092 / median length = 4.782 / last = 4.0628 / epsilon = 0.2870 / lr = 0.0036
# Ep 2090. Loss = 0.088 / median length = 4.765 / last = 4.9074 / epsilon = 0.2853 / lr = 0.0036
# Ep 2100 | current sol: [7] / next est reward: -5.645387172698975
# Ep 2100 | current sol: [7, 1] / next est reward: -5.454296112060547
# Ep 2100 | current sol: [7, 1, 2, 3] / next est reward: -4.9506025314331055
# Ep 2100 | current sol: [7, 1, 2, 3, 5, 8] / next est reward: -3.929675817489624
# Ep 2100 | current sol: [7, 1, 2, 3, 5, 8, 9] / next est reward: -3.488752603530884
# Ep 2100 | current sol: [7, 1, 2, 3, 5, 8, 9, 4] / next est reward: -2.842240333557129
# Ep 2100. Loss = 0.096 / median length = 4.706 / last = 5.0718 / epsilon = 0.2835 / lr = 0.0036
# Ep 2110. Loss = 0.162 / median length = 4.640 / last = 3.8764 / epsilon = 0.2819 / lr = 0.0036
# Ep 2120. Loss = 0.145 / median length = 4.562 / last = 4.9762 / epsilon = 0.2802 / lr = 0.0036
# Ep 2130. Loss = 0.218 / median length = 4.622 / last = 5.4542 / epsilon = 0.2785 / lr = 0.0035
# Ep 2140. Loss = 0.101 / median length = 4.494 / last = 4.4883 / epsilon = 0.2768 / lr = 0.0035
# Ep 2150 | current sol: [4] / next est reward: -5.701687812805176
# Ep 2150 | current sol: [4, 3] / next est reward: -5.480041980743408
# Ep 2150 | current sol: [4, 3, 2] / next est reward: -5.394305229187012
# Ep 2150 | current sol: [4, 3, 2, 8, 5, 6] / next est reward: -4.1586527824401855
# Ep 2150 | current sol: [4, 3, 2, 8, 5, 6, 9] / next est reward: -3.442225456237793
# Ep 2150 | current sol: [4, 3, 2, 8, 5, 6, 9, 0] / next est reward: -2.611253023147583
# Ep 2150 | current sol: [4, 3, 2, 8, 5, 6, 9, 0, 1] / next est reward: -1.8562493324279785
# Ep 2150. Loss = 0.116 / median length = 4.464 / last = 3.9041 / epsilon = 0.2752 / lr = 0.0035
# Ep 2160. Loss = 0.119 / median length = 4.524 / last = 4.7537 / epsilon = 0.2735 / lr = 0.0035
# Ep 2170. Loss = 0.078 / median length = 4.528 / last = 3.9834 / epsilon = 0.2719 / lr = 0.0035
# Ep 2180. Loss = 0.161 / median length = 4.612 / last = 5.9647 / epsilon = 0.2703 / lr = 0.0035
# Ep 2190. Loss = 0.274 / median length = 4.667 / last = 3.6576 / epsilon = 0.2686 / lr = 0.0035
# Ep 2200 | current sol: [7] / next est reward: -4.833467483520508
# Ep 2200 | current sol: [7, 5] / next est reward: -4.74092960357666
# Ep 2200 | current sol: [7, 5, 3] / next est reward: -4.663408279418945
# Ep 2200 | current sol: [7, 5, 3, 4] / next est reward: -4.573840141296387
# Ep 2200 | current sol: [7, 5, 3, 4, 8] / next est reward: -4.549421310424805
# Ep 2200 | current sol: [7, 5, 3, 4, 8, 6, 9] / next est reward: -2.974691390991211
# Ep 2200 | current sol: [7, 5, 3, 4, 8, 6, 9, 0] / next est reward: -2.762138605117798
# Ep 2200. Loss = 0.119 / median length = 4.743 / last = 4.7318 / epsilon = 0.2670 / lr = 0.0035
# Ep 2210. Loss = 0.134 / median length = 4.911 / last = 4.0588 / epsilon = 0.2654 / lr = 0.0035
# Ep 2220. Loss = 0.234 / median length = 4.922 / last = 5.7343 / epsilon = 0.2638 / lr = 0.0035
# Ep 2230. Loss = 0.211 / median length = 4.851 / last = 6.5606 / epsilon = 0.2623 / lr = 0.0035
# Ep 2240. Loss = 0.152 / median length = 4.948 / last = 4.4108 / epsilon = 0.2607 / lr = 0.0035
# Ep 2250 | current sol: [9] / next est reward: -5.086760520935059
# Ep 2250 | current sol: [9, 6] / next est reward: -5.010254383087158
# Ep 2250 | current sol: [9, 6, 8] / next est reward: -4.923214912414551
# Ep 2250 | current sol: [9, 6, 8, 4] / next est reward: -4.828199863433838
# Ep 2250 | current sol: [9, 6, 8, 4, 0, 7] / next est reward: -3.7671775817871094
# Ep 2250 | current sol: [9, 6, 8, 4, 0, 7, 3] / next est reward: -3.110271453857422
# Ep 2250 | current sol: [9, 6, 8, 4, 0, 7, 3, 5] / next est reward: -2.38814640045166
# Ep 2250 | current sol: [9, 6, 8, 4, 0, 7, 3, 5, 2] / next est reward: -1.7248704433441162
# Ep 2250. Loss = 0.101 / median length = 4.878 / last = 4.3935 / epsilon = 0.2591 / lr = 0.0035
# Ep 2260. Loss = 0.247 / median length = 4.764 / last = 4.3695 / epsilon = 0.2576 / lr = 0.0035
# Ep 2270. Loss = 0.081 / median length = 4.735 / last = 4.6743 / epsilon = 0.2560 / lr = 0.0035
# Ep 2280. Loss = 0.160 / median length = 4.705 / last = 5.9068 / epsilon = 0.2545 / lr = 0.0035
# Ep 2290. Loss = 0.106 / median length = 4.579 / last = 3.3433 / epsilon = 0.2530 / lr = 0.0034
# Ep 2300 | current sol: [7] / next est reward: -7.402817726135254
# Ep 2300 | current sol: [7, 3, 8] / next est reward: -6.765754699707031
# Ep 2300 | current sol: [7, 3, 8, 1] / next est reward: -6.420880317687988
# Ep 2300 | current sol: [7, 3, 8, 1, 6] / next est reward: -6.076714992523193
# Ep 2300 | current sol: [7, 3, 8, 1, 6, 0] / next est reward: -5.628361225128174
# Ep 2300 | current sol: [7, 3, 8, 1, 6, 0, 4, 9] / next est reward: -3.22013521194458
# Ep 2300 | current sol: [7, 3, 8, 1, 6, 0, 4, 9, 2] / next est reward: -2.088627576828003
# Ep 2300. Loss = 0.105 / median length = 4.787 / last = 5.5879 / epsilon = 0.2515 / lr = 0.0034
# Ep 2310. Loss = 0.176 / median length = 4.877 / last = 4.0846 / epsilon = 0.2500 / lr = 0.0034
# Ep 2320. Loss = 0.130 / median length = 4.848 / last = 4.0710 / epsilon = 0.2485 / lr = 0.0034
# Ep 2330. Loss = 0.217 / median length = 4.770 / last = 3.7724 / epsilon = 0.2470 / lr = 0.0034
# Ep 2340. Loss = 0.137 / median length = 4.817 / last = 4.5270 / epsilon = 0.2455 / lr = 0.0034
# Ep 2350 | current sol: [9] / next est reward: -5.69923210144043
# Ep 2350 | current sol: [9, 1, 0] / next est reward: -5.20090389251709
# Ep 2350 | current sol: [9, 1, 0, 4, 2] / next est reward: -4.5808844566345215
# Ep 2350 | current sol: [9, 1, 0, 4, 2, 5] / next est reward: -3.9787583351135254
# Ep 2350 | current sol: [9, 1, 0, 4, 2, 5, 8] / next est reward: -3.5334882736206055
# Ep 2350 | current sol: [9, 1, 0, 4, 2, 5, 8, 6] / next est reward: -2.8943347930908203
# Ep 2350 | current sol: [9, 1, 0, 4, 2, 5, 8, 6, 7] / next est reward: -2.0909788608551025
# Ep 2350. Loss = 0.083 / median length = 4.779 / last = 3.7777 / epsilon = 0.2440 / lr = 0.0034
# Ep 2360. Loss = 0.187 / median length = 4.784 / last = 3.9441 / epsilon = 0.2426 / lr = 0.0034
# Ep 2370. Loss = 0.217 / median length = 4.692 / last = 4.6844 / epsilon = 0.2411 / lr = 0.0034
# Ep 2380. Loss = 0.149 / median length = 4.688 / last = 4.6924 / epsilon = 0.2397 / lr = 0.0034
# Ep 2390. Loss = 0.162 / median length = 4.597 / last = 6.4346 / epsilon = 0.2383 / lr = 0.0034
# Ep 2400 | current sol: [9, 8] / next est reward: -5.958383560180664
# Ep 2400 | current sol: [9, 8, 5] / next est reward: -5.822993278503418
# Ep 2400 | current sol: [9, 8, 5, 4] / next est reward: -5.716094017028809
# Ep 2400 | current sol: [9, 8, 5, 4, 7] / next est reward: -5.507706642150879
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0] / next est reward: -5.2255120277404785
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0, 3] / next est reward: -4.6113386154174805
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0, 3, 6] / next est reward: -3.886542320251465
# Ep 2400 | current sol: [9, 8, 5, 4, 7, 0, 3, 6, 2] / next est reward: -2.679425001144409
# Ep 2400. Loss = 0.159 / median length = 4.561 / last = 5.8423 / epsilon = 0.2368 / lr = 0.0034
# Ep 2410. Loss = 0.194 / median length = 4.491 / last = 6.8376 / epsilon = 0.2354 / lr = 0.0034
# Ep 2420. Loss = 0.180 / median length = 4.430 / last = 4.2828 / epsilon = 0.2340 / lr = 0.0034
# Ep 2430. Loss = 0.126 / median length = 4.392 / last = 4.7886 / epsilon = 0.2326 / lr = 0.0034
# Ep 2440. Loss = 0.205 / median length = 4.431 / last = 3.4547 / epsilon = 0.2312 / lr = 0.0034
# Ep 2450 | current sol: [1, 9] / next est reward: -7.145283222198486
# Ep 2450 | current sol: [1, 9, 0] / next est reward: -6.924797058105469
# Ep 2450 | current sol: [1, 9, 0, 6] / next est reward: -6.612000942230225
# Ep 2450 | current sol: [1, 9, 0, 6, 2] / next est reward: -6.30260705947876
# Ep 2450 | current sol: [1, 9, 0, 6, 2, 8] / next est reward: -5.628533363342285
# Ep 2450 | current sol: [1, 9, 0, 6, 2, 8, 5] / next est reward: -4.5007643699646
# Ep 2450 | current sol: [1, 9, 0, 6, 2, 8, 5, 3, 4] / next est reward: -2.042522430419922
# Ep 2450. Loss = 0.162 / median length = 4.431 / last = 4.8575 / epsilon = 0.2298 / lr = 0.0033
# Ep 2460. Loss = 0.100 / median length = 4.388 / last = 4.0442 / epsilon = 0.2284 / lr = 0.0033
# Ep 2470. Loss = 0.125 / median length = 4.388 / last = 3.5807 / epsilon = 0.2271 / lr = 0.0033
# Ep 2480. Loss = 0.193 / median length = 4.343 / last = 3.9441 / epsilon = 0.2257 / lr = 0.0033
# Ep 2490. Loss = 0.206 / median length = 4.303 / last = 5.3721 / epsilon = 0.2244 / lr = 0.0033
# Ep 2500 | current sol: [3] / next est reward: -6.5192341804504395
# Ep 2500 | current sol: [3, 6] / next est reward: -6.335339069366455
# Ep 2500 | current sol: [3, 6, 1] / next est reward: -6.178750038146973
# Ep 2500 | current sol: [3, 6, 1, 0] / next est reward: -6.082610130310059
# Ep 2500 | current sol: [3, 6, 1, 0, 7, 8, 2, 4] / next est reward: -3.925957679748535
# Ep 2500 | current sol: [3, 6, 1, 0, 7, 8, 2, 4, 5] / next est reward: -3.235342264175415
# Ep 2500. Loss = 0.187 / median length = 4.410 / last = 5.3862 / epsilon = 0.2230 / lr = 0.0033
# Ep 2510. Loss = 0.088 / median length = 4.538 / last = 4.4843 / epsilon = 0.2217 / lr = 0.0033
# Ep 2520. Loss = 0.137 / median length = 4.760 / last = 4.3143 / epsilon = 0.2204 / lr = 0.0033
# Ep 2530. Loss = 0.128 / median length = 4.770 / last = 5.4704 / epsilon = 0.2190 / lr = 0.0033
# Ep 2540. Loss = 0.254 / median length = 4.708 / last = 3.3071 / epsilon = 0.2177 / lr = 0.0033
# Ep 2550 | current sol: [7] / next est reward: -5.961637496948242
# Ep 2550 | current sol: [7, 4] / next est reward: -5.684682369232178
# Ep 2550 | current sol: [7, 4, 2] / next est reward: -5.424527168273926
# Ep 2550 | current sol: [7, 4, 2, 9] / next est reward: -5.289411544799805
# Ep 2550 | current sol: [7, 4, 2, 9, 3] / next est reward: -5.104281425476074
# Ep 2550 | current sol: [7, 4, 2, 9, 3, 0, 8] / next est reward: -4.044198513031006
# Ep 2550 | current sol: [7, 4, 2, 9, 3, 0, 8, 6] / next est reward: -4.042645454406738
# Ep 2550 | current sol: [7, 4, 2, 9, 3, 0, 8, 6, 1] / next est reward: -2.782681703567505
# Ep 2550. Loss = 0.130 / median length = 4.476 / last = 3.7478 / epsilon = 0.2164 / lr = 0.0033
# Ep 2560. Loss = 0.113 / median length = 4.566 / last = 4.4479 / epsilon = 0.2151 / lr = 0.0033
# Ep 2570. Loss = 0.192 / median length = 4.408 / last = 3.6408 / epsilon = 0.2139 / lr = 0.0033
# Ep 2580. Loss = 0.119 / median length = 4.291 / last = 3.5679 / epsilon = 0.2126 / lr = 0.0033
# Ep 2590. Loss = 0.195 / median length = 4.217 / last = 3.8355 / epsilon = 0.2113 / lr = 0.0033
# Ep 2600 | current sol: [2] / next est reward: -5.65499210357666
# Ep 2600 | current sol: [2, 1] / next est reward: -5.5399298667907715
# Ep 2600 | current sol: [2, 1, 0, 8] / next est reward: -4.824030876159668
# Ep 2600 | current sol: [2, 1, 0, 8, 5] / next est reward: -4.646004676818848
# Ep 2600 | current sol: [2, 1, 0, 8, 5, 3] / next est reward: -4.282947063446045
# Ep 2600 | current sol: [2, 1, 0, 8, 5, 3, 9, 7] / next est reward: -3.288156032562256
# Ep 2600 | current sol: [2, 1, 0, 8, 5, 3, 9, 7, 6] / next est reward: -2.1479945182800293
# Ep 2600. Loss = 0.114 / median length = 4.352 / last = 4.3519 / epsilon = 0.2100 / lr = 0.0033
# Ep 2610. Loss = 0.110 / median length = 4.322 / last = 4.2693 / epsilon = 0.2088 / lr = 0.0033
# Ep 2620. Loss = 0.117 / median length = 4.390 / last = 5.8381 / epsilon = 0.2075 / lr = 0.0032
# Ep 2630. Loss = 0.064 / median length = 4.474 / last = 7.2697 / epsilon = 0.2063 / lr = 0.0032
# Ep 2640. Loss = 0.054 / median length = 4.474 / last = 4.3846 / epsilon = 0.2051 / lr = 0.0032
# Ep 2650 | current sol: [4] / next est reward: -5.164244174957275
# Ep 2650 | current sol: [4, 9] / next est reward: -5.098738670349121
# Ep 2650 | current sol: [4, 9, 8] / next est reward: -5.028017997741699
# Ep 2650 | current sol: [4, 9, 8, 2] / next est reward: -4.986639499664307
# Ep 2650 | current sol: [4, 9, 8, 2, 1] / next est reward: -4.863217353820801
# Ep 2650 | current sol: [4, 9, 8, 2, 1, 6] / next est reward: -4.363539218902588
# Ep 2650 | current sol: [4, 9, 8, 2, 1, 6, 5] / next est reward: -3.87088680267334
# Ep 2650 | current sol: [4, 9, 8, 2, 1, 6, 5, 7] / next est reward: -3.0689332485198975
# Ep 2650 | current sol: [4, 9, 8, 2, 1, 6, 5, 7, 3] / next est reward: -3.0569701194763184
# Ep 2650. Loss = 0.171 / median length = 4.366 / last = 3.0305 / epsilon = 0.2038 / lr = 0.0032
# Ep 2660. Loss = 0.166 / median length = 4.344 / last = 5.3256 / epsilon = 0.2026 / lr = 0.0032
# Ep 2670. Loss = 0.249 / median length = 4.322 / last = 4.7953 / epsilon = 0.2014 / lr = 0.0032
# Ep 2680. Loss = 0.271 / median length = 4.322 / last = 3.3890 / epsilon = 0.2002 / lr = 0.0032
# Ep 2690. Loss = 0.092 / median length = 4.316 / last = 3.3223 / epsilon = 0.1990 / lr = 0.0032
# Ep 2700 | current sol: [0] / next est reward: -7.228513717651367
# Ep 2700 | current sol: [0, 3] / next est reward: -6.99169397354126
# Ep 2700 | current sol: [0, 3, 9] / next est reward: -6.89020299911499
# Ep 2700 | current sol: [0, 3, 9, 2] / next est reward: -6.65653133392334
# Ep 2700 | current sol: [0, 3, 9, 2, 4] / next est reward: -6.651040554046631
# Ep 2700 | current sol: [0, 3, 9, 2, 4, 1, 5] / next est reward: -5.194215774536133
# Ep 2700 | current sol: [0, 3, 9, 2, 4, 1, 5, 8] / next est reward: -4.642761707305908
# Ep 2700 | current sol: [0, 3, 9, 2, 4, 1, 5, 8, 6] / next est reward: -3.014075994491577
# Ep 2700. Loss = 0.263 / median length = 4.494 / last = 5.4818 / epsilon = 0.1978 / lr = 0.0032
# Ep 2710. Loss = 0.126 / median length = 4.608 / last = 5.8200 / epsilon = 0.1966 / lr = 0.0032
# Ep 2720. Loss = 0.147 / median length = 4.251 / last = 3.1516 / epsilon = 0.1954 / lr = 0.0032
# Ep 2730. Loss = 0.158 / median length = 4.476 / last = 4.5771 / epsilon = 0.1943 / lr = 0.0032
# Ep 2740. Loss = 0.117 / median length = 4.441 / last = 4.4119 / epsilon = 0.1931 / lr = 0.0032
# Ep 2750 | current sol: [4] / next est reward: -4.293627738952637
# Ep 2750 | current sol: [4, 6] / next est reward: -4.374236106872559
# Ep 2750 | current sol: [4, 6, 1] / next est reward: -4.212733268737793
# Ep 2750 | current sol: [4, 6, 1, 0, 8] / next est reward: -3.5717356204986572
# Ep 2750 | current sol: [4, 6, 1, 0, 8, 7] / next est reward: -3.743715763092041
# Ep 2750 | current sol: [4, 6, 1, 0, 8, 7, 3] / next est reward: -3.122487783432007
# Ep 2750 | current sol: [4, 6, 1, 0, 8, 7, 3, 9, 2] / next est reward: -1.8093945980072021
# Ep 2750. Loss = 0.150 / median length = 4.433 / last = 4.5415 / epsilon = 0.1920 / lr = 0.0032
# Ep 2760. Loss = 0.096 / median length = 4.351 / last = 4.2135 / epsilon = 0.1908 / lr = 0.0032
# Ep 2770. Loss = 0.068 / median length = 4.395 / last = 4.5390 / epsilon = 0.1897 / lr = 0.0032
# Ep 2780. Loss = 0.313 / median length = 4.256 / last = 5.3474 / epsilon = 0.1885 / lr = 0.0032
# Ep 2790. Loss = 0.171 / median length = 4.218 / last = 5.3096 / epsilon = 0.1874 / lr = 0.0031
# Ep 2800 | current sol: [9, 0] / next est reward: -5.880870819091797
# Ep 2800 | current sol: [9, 0, 2] / next est reward: -5.779369831085205
# Ep 2800 | current sol: [9, 0, 2, 6, 4] / next est reward: -5.052655220031738
# Ep 2800 | current sol: [9, 0, 2, 6, 4, 5] / next est reward: -4.497375965118408
# Ep 2800 | current sol: [9, 0, 2, 6, 4, 5, 1] / next est reward: -3.69588041305542
# Ep 2800 | current sol: [9, 0, 2, 6, 4, 5, 1, 8, 7] / next est reward: -2.498821973800659
# Ep 2800. Loss = 0.121 / median length = 4.159 / last = 4.6101 / epsilon = 0.1863 / lr = 0.0031
# Ep 2810. Loss = 0.261 / median length = 4.194 / last = 4.2179 / epsilon = 0.1852 / lr = 0.0031
# Ep 2820. Loss = 0.083 / median length = 4.304 / last = 3.9813 / epsilon = 0.1841 / lr = 0.0031
# Ep 2830. Loss = 0.126 / median length = 4.323 / last = 5.0863 / epsilon = 0.1830 / lr = 0.0031
# Ep 2840. Loss = 0.169 / median length = 4.340 / last = 4.5965 / epsilon = 0.1819 / lr = 0.0031
# Ep 2850 | current sol: [6] / next est reward: -6.123410701751709
# Ep 2850 | current sol: [6, 5] / next est reward: -5.885664939880371
# Ep 2850 | current sol: [6, 5, 1, 7, 9, 2, 0] / next est reward: -2.758669853210449
# Ep 2850 | current sol: [6, 5, 1, 7, 9, 2, 0, 4] / next est reward: -2.022351026535034
# Ep 2850 | current sol: [6, 5, 1, 7, 9, 2, 0, 4, 3] / next est reward: -1.5848032236099243
# Ep 2850. Loss = 0.163 / median length = 4.516 / last = 4.6138 / epsilon = 0.1808 / lr = 0.0031
# Ep 2860. Loss = 0.140 / median length = 4.492 / last = 6.4041 / epsilon = 0.1797 / lr = 0.0031
# Ep 2870. Loss = 0.145 / median length = 4.575 / last = 4.0497 / epsilon = 0.1786 / lr = 0.0031
# Ep 2880. Loss = 0.140 / median length = 4.575 / last = 3.6721 / epsilon = 0.1775 / lr = 0.0031
# ...
# Ep 3300 | current sol: [2, 1, 4, 9, 5, 7, 6] / next est reward: -4.632615566253662
# Ep 3300 | current sol: [2, 1, 4, 9, 5, 7, 6, 8] / next est reward: -3.6822006702423096
# Ep 3300 | current sol: [2, 1, 4, 9, 5, 7, 6, 8, 3] / next est reward: -2.4435372352600098
# Ep 3300. Loss = 0.230 / median length = 4.099 / last = 5.7623 / epsilon = 0.1380 / lr = 0.0029
# Ep 3310. Loss = 0.125 / median length = 4.118 / last = 3.7417 / epsilon = 0.1372 / lr = 0.0029
# Ep 3320. Loss = 0.088 / median length = 4.235 / last = 4.9019 / epsilon = 0.1363 / lr = 0.0029
# Ep 3330. Loss = 0.122 / median length = 4.293 / last = 5.4159 / epsilon = 0.1355 / lr = 0.0029
# Ep 3340. Loss = 0.143 / median length = 4.333 / last = 5.8414 / epsilon = 0.1347 / lr = 0.0029
# Ep 3350 | current sol: [8] / next est reward: -7.015197277069092
# Ep 3350 | current sol: [8, 9] / next est reward: -6.803202152252197
# Ep 3350 | current sol: [8, 9, 5] / next est reward: -6.581073760986328
# Ep 3350 | current sol: [8, 9, 5, 2] / next est reward: -6.366407871246338
# Ep 3350 | current sol: [8, 9, 5, 2, 1, 7, 6] / next est reward: -3.951322555541992
# Ep 3350 | current sol: [8, 9, 5, 2, 1, 7, 6, 4] / next est reward: -3.7155261039733887
# Ep 3350 | current sol: [8, 9, 5, 2, 1, 7, 6, 4, 0] / next est reward: -2.530001401901245
# Ep 3350. Loss = 0.145 / median length = 4.401 / last = 6.4142 / epsilon = 0.1339 / lr = 0.0028
# Ep 3360. Loss = 0.095 / median length = 4.483 / last = 4.1365 / epsilon = 0.1331 / lr = 0.0028
# Ep 3370. Loss = 0.186 / median length = 4.453 / last = 4.1023 / epsilon = 0.1323 / lr = 0.0028
# Ep 3380. Loss = 0.217 / median length = 4.472 / last = 3.7453 / epsilon = 0.1315 / lr = 0.0028
# Ep 3390. Loss = 0.090 / median length = 4.281 / last = 4.1050 / epsilon = 0.1307 / lr = 0.0028
# Ep 3400 | current sol: [9] / next est reward: -4.047319412231445
# Ep 3400 | current sol: [9, 8, 4] / next est reward: -4.104253768920898
# Ep 3400 | current sol: [9, 8, 4, 2] / next est reward: -3.9915852546691895
# Ep 3400 | current sol: [9, 8, 4, 2, 0] / next est reward: -3.8194828033447266
# Ep 3400 | current sol: [9, 8, 4, 2, 0, 1] / next est reward: -3.3558316230773926
# Ep 3400 | current sol: [9, 8, 4, 2, 0, 1, 3] / next est reward: -2.922436237335205
# Ep 3400 | current sol: [9, 8, 4, 2, 0, 1, 3, 7] / next est reward: -2.578338861465454
# Ep 3400 | current sol: [9, 8, 4, 2, 0, 1, 3, 7, 6] / next est reward: -2.1022536754608154
# Ep 3400. Loss = 0.109 / median length = 4.243 / last = 4.2370 / epsilon = 0.1299 / lr = 0.0028
# Ep 3410. Loss = 0.061 / median length = 4.281 / last = 6.4643 / epsilon = 0.1292 / lr = 0.0028
# Ep 3420. Loss = 0.151 / median length = 4.243 / last = 3.9514 / epsilon = 0.1284 / lr = 0.0028
# Ep 3430. Loss = 0.142 / median length = 4.339 / last = 6.1860 / epsilon = 0.1276 / lr = 0.0028
# Ep 3440. Loss = 0.191 / median length = 4.474 / last = 5.4556 / epsilon = 0.1269 / lr = 0.0028
# Ep 3450 | current sol: [1] / next est reward: -4.518655300140381
# Ep 3450 | current sol: [1, 0] / next est reward: -4.534826755523682
# Ep 3450 | current sol: [1, 0, 4] / next est reward: -4.693872451782227
# Ep 3450 | current sol: [1, 0, 4, 6] / next est reward: -4.650862693786621
# Ep 3450 | current sol: [1, 0, 4, 6, 8] / next est reward: -4.606484889984131
# Ep 3450 | current sol: [1, 0, 4, 6, 8, 9] / next est reward: -4.91419792175293
# Ep 3450 | current sol: [1, 0, 4, 6, 8, 9, 3] / next est reward: -4.479560852050781
# Ep 3450 | current sol: [1, 0, 4, 6, 8, 9, 3, 5, 7] / next est reward: -3.1145741939544678
# Ep 3450. Loss = 0.091 / median length = 4.474 / last = 3.5097 / epsilon = 0.1261 / lr = 0.0028
# Ep 3460. Loss = 0.145 / median length = 4.333 / last = 2.8811 / epsilon = 0.1254 / lr = 0.0028
# Ep 3470. Loss = 0.140 / median length = 4.361 / last = 3.0464 / epsilon = 0.1246 / lr = 0.0028
# Ep 3480. Loss = 0.216 / median length = 4.271 / last = 4.2683 / epsilon = 0.1239 / lr = 0.0028
# Ep 3490. Loss = 0.119 / median length = 4.221 / last = 4.7032 / epsilon = 0.1231 / lr = 0.0028
# Ep 3500 | current sol: [4] / next est reward: -4.818986892700195
# Ep 3500 | current sol: [4, 9] / next est reward: -4.94169282913208
# Ep 3500 | current sol: [4, 9, 7] / next est reward: -5.154689788818359
# Ep 3500 | current sol: [4, 9, 7, 0] / next est reward: -5.122763156890869
# Ep 3500 | current sol: [4, 9, 7, 0, 3] / next est reward: -5.006052494049072
# Ep 3500 | current sol: [4, 9, 7, 0, 3, 2] / next est reward: -4.594729423522949
# Ep 3500 | current sol: [4, 9, 7, 0, 3, 2, 1] / next est reward: -4.084308624267578
# Ep 3500 | current sol: [4, 9, 7, 0, 3, 2, 1, 5] / next est reward: -3.5536205768585205
# Ep 3500 | current sol: [4, 9, 7, 0, 3, 2, 1, 5, 8] / next est reward: -2.4113094806671143
# Ep 3500. Loss = 0.088 / median length = 4.246 / last = 4.5226 / epsilon = 0.1224 / lr = 0.0028
# Ep 3510. Loss = 0.248 / median length = 4.543 / last = 5.6028 / epsilon = 0.1216 / lr = 0.0028
# Ep 3520. Loss = 0.152 / median length = 4.489 / last = 3.4345 / epsilon = 0.1209 / lr = 0.0028
# Ep 3530. Loss = 0.124 / median length = 4.447 / last = 3.7748 / epsilon = 0.1202 / lr = 0.0028
# Ep 3540. Loss = 0.203 / median length = 4.362 / last = 3.7739 / epsilon = 0.1195 / lr = 0.0028
# Ep 3550 | current sol: [1] / next est reward: -5.3384809494018555
# Ep 3550 | current sol: [1, 5] / next est reward: -5.2735514640808105
# Ep 3550 | current sol: [1, 5, 2] / next est reward: -5.198657989501953
# Ep 3550 | current sol: [1, 5, 2, 9] / next est reward: -5.1163763999938965
# Ep 3550 | current sol: [1, 5, 2, 9, 0] / next est reward: -5.640917778015137
# Ep 3550 | current sol: [1, 5, 2, 9, 0, 4] / next est reward: -5.317704200744629
# Ep 3550 | current sol: [1, 5, 2, 9, 0, 4, 3] / next est reward: -4.804664134979248
# Ep 3550 | current sol: [1, 5, 2, 9, 0, 4, 3, 6] / next est reward: -3.54624080657959
# Ep 3550 | current sol: [1, 5, 2, 9, 0, 4, 3, 6, 8] / next est reward: -2.951550245285034
# Ep 3550. Loss = 0.083 / median length = 4.362 / last = 4.3366 / epsilon = 0.1188 / lr = 0.0027
# Ep 3560. Loss = 0.120 / median length = 4.232 / last = 4.4196 / epsilon = 0.1181 / lr = 0.0027
# Ep 3570. Loss = 0.139 / median length = 4.349 / last = 3.3436 / epsilon = 0.1173 / lr = 0.0027
# Ep 3580. Loss = 0.195 / median length = 4.327 / last = 3.6225 / epsilon = 0.1166 / lr = 0.0027
# Ep 3590. Loss = 0.114 / median length = 4.365 / last = 4.6193 / epsilon = 0.1159 / lr = 0.0027
# Ep 3600 | current sol: [9] / next est reward: -4.884587287902832
# Ep 3600 | current sol: [9, 7] / next est reward: -5.028409004211426
# Ep 3600 | current sol: [9, 7, 2] / next est reward: -4.928855895996094
# Ep 3600 | current sol: [9, 7, 2, 3] / next est reward: -4.780584335327148
# Ep 3600 | current sol: [9, 7, 2, 3, 8] / next est reward: -4.593625545501709
# Ep 3600 | current sol: [9, 7, 2, 3, 8, 0] / next est reward: -4.403658866882324
# Ep 3600 | current sol: [9, 7, 2, 3, 8, 0, 6] / next est reward: -4.467458248138428
# Ep 3600 | current sol: [9, 7, 2, 3, 8, 0, 6, 5] / next est reward: -3.573331832885742
# Ep 3600 | current sol: [9, 7, 2, 3, 8, 0, 6, 5, 4] / next est reward: -2.922248363494873
# Ep 3600. Loss = 0.265 / median length = 4.310 / last = 3.2030 / epsilon = 0.1153 / lr = 0.0027
# Ep 3610. Loss = 0.126 / median length = 4.266 / last = 3.3619 / epsilon = 0.1146 / lr = 0.0027
# Ep 3620. Loss = 0.138 / median length = 4.266 / last = 3.9310 / epsilon = 0.1139 / lr = 0.0027
# Ep 3630. Loss = 0.081 / median length = 4.548 / last = 4.4827 / epsilon = 0.1132 / lr = 0.0027
# Ep 3640. Loss = 0.159 / median length = 4.460 / last = 4.4880 / epsilon = 0.1125 / lr = 0.0027
# Ep 3650 | current sol: [5] / next est reward: -6.138541221618652
# Ep 3650 | current sol: [5, 4] / next est reward: -6.176166534423828
# Ep 3650 | current sol: [5, 4, 9] / next est reward: -6.13754940032959
# Ep 3650 | current sol: [5, 4, 9, 7] / next est reward: -5.943525791168213
# Ep 3650 | current sol: [5, 4, 9, 7, 6] / next est reward: -5.761013984680176
# Ep 3650 | current sol: [5, 4, 9, 7, 6, 1] / next est reward: -5.549457550048828
# Ep 3650 | current sol: [5, 4, 9, 7, 6, 1, 2] / next est reward: -4.718446731567383
# Ep 3650 | current sol: [5, 4, 9, 7, 6, 1, 2, 3, 8] / next est reward: -2.4210205078125
# Ep 3650. Loss = 0.239 / median length = 4.426 / last = 5.0437 / epsilon = 0.1118 / lr = 0.0027
# Ep 3660. Loss = 0.186 / median length = 4.468 / last = 4.5466 / epsilon = 0.1112 / lr = 0.0027
# Ep 3670. Loss = 0.238 / median length = 4.440 / last = 3.5165 / epsilon = 0.1105 / lr = 0.0027
# Ep 3680. Loss = 0.111 / median length = 4.326 / last = 4.1553 / epsilon = 0.1098 / lr = 0.0027
# Ep 3690. Loss = 0.202 / median length = 4.286 / last = 4.2423 / epsilon = 0.1092 / lr = 0.0027
# Ep 3700 | current sol: [5] / next est reward: -5.8613691329956055
# Ep 3700 | current sol: [5, 8] / next est reward: -5.9441914558410645
# Ep 3700 | current sol: [5, 8, 0] / next est reward: -5.989725589752197
# Ep 3700 | current sol: [5, 8, 0, 1] / next est reward: -5.758932113647461
# Ep 3700 | current sol: [5, 8, 0, 1, 3] / next est reward: -5.485739707946777
# Ep 3700 | current sol: [5, 8, 0, 1, 3, 6] / next est reward: -5.263497352600098
# Ep 3700 | current sol: [5, 8, 0, 1, 3, 6, 4] / next est reward: -4.595788955688477
# Ep 3700 | current sol: [5, 8, 0, 1, 3, 6, 4, 9] / next est reward: -3.602264404296875
# Ep 3700 | current sol: [5, 8, 0, 1, 3, 6, 4, 9, 2] / next est reward: -2.5427160263061523
# Ep 3700. Loss = 0.147 / median length = 4.263 / last = 5.0281 / epsilon = 0.1085 / lr = 0.0027
# Ep 3710. Loss = 0.107 / median length = 4.245 / last = 3.2518 / epsilon = 0.1079 / lr = 0.0027
# Ep 3720. Loss = 0.198 / median length = 4.205 / last = 4.1774 / epsilon = 0.1072 / lr = 0.0027
# Ep 3730. Loss = 0.051 / median length = 4.410 / last = 4.8502 / epsilon = 0.1066 / lr = 0.0027
# Ep 3740. Loss = 0.226 / median length = 4.466 / last = 4.1562 / epsilon = 0.1060 / lr = 0.0027
# Ep 3750 | current sol: [5] / next est reward: -5.327182769775391
# Ep 3750 | current sol: [5, 9] / next est reward: -5.502019882202148
# Ep 3750 | current sol: [5, 9, 2] / next est reward: -5.50926399230957
# Ep 3750 | current sol: [5, 9, 2, 0] / next est reward: -5.758400917053223
# Ep 3750 | current sol: [5, 9, 2, 0, 3] / next est reward: -5.450127601623535
# Ep 3750 | current sol: [5, 9, 2, 0, 3, 4] / next est reward: -5.335145473480225
# Ep 3750 | current sol: [5, 9, 2, 0, 3, 4, 7] / next est reward: -4.705468654632568
# Ep 3750 | current sol: [5, 9, 2, 0, 3, 4, 7, 1] / next est reward: -3.877974033355713
# Ep 3750. Loss = 0.301 / median length = 4.205 / last = 4.0783 / epsilon = 0.1053 / lr = 0.0026
# Ep 3760. Loss = 0.180 / median length = 4.205 / last = 4.2357 / epsilon = 0.1047 / lr = 0.0026
# Ep 3770. Loss = 0.057 / median length = 4.194 / last = 4.2507 / epsilon = 0.1041 / lr = 0.0026
# Ep 3780. Loss = 0.096 / median length = 4.143 / last = 4.8354 / epsilon = 0.1034 / lr = 0.0026
# Ep 3790. Loss = 0.129 / median length = 4.233 / last = 3.9287 / epsilon = 0.1028 / lr = 0.0026
# Ep 3800 | current sol: [0] / next est reward: -5.352369785308838
# Ep 3800 | current sol: [0, 3] / next est reward: -5.507919788360596
# Ep 3800 | current sol: [0, 3, 7] / next est reward: -5.620723724365234
# Ep 3800 | current sol: [0, 3, 7, 2] / next est reward: -5.557745456695557
# Ep 3800 | current sol: [0, 3, 7, 2, 1] / next est reward: -5.573636054992676
# Ep 3800 | current sol: [0, 3, 7, 2, 1, 8] / next est reward: -5.530514717102051
# Ep 3800 | current sol: [0, 3, 7, 2, 1, 8, 5] / next est reward: -4.548655986785889
# Ep 3800 | current sol: [0, 3, 7, 2, 1, 8, 5, 6] / next est reward: -3.4993302822113037
# Ep 3800 | current sol: [0, 3, 7, 2, 1, 8, 5, 6, 4] / next est reward: -2.4321670532226562
# Ep 3800. Loss = 0.159 / median length = 4.418 / last = 3.5439 / epsilon = 0.1022 / lr = 0.0026
# Ep 3810. Loss = 0.133 / median length = 4.418 / last = 4.5721 / epsilon = 0.1016 / lr = 0.0026
# Ep 3820. Loss = 0.228 / median length = 4.584 / last = 4.4643 / epsilon = 0.1010 / lr = 0.0026
# Ep 3830. Loss = 0.094 / median length = 4.481 / last = 3.0902 / epsilon = 0.1004 / lr = 0.0026
# Ep 3840. Loss = 0.099 / median length = 4.294 / last = 4.3070 / epsilon = 0.1000 / lr = 0.0026
# Ep 3850 | current sol: [8] / next est reward: -3.8554165363311768
# Ep 3850 | current sol: [8, 0] / next est reward: -3.9361329078674316
# Ep 3850 | current sol: [8, 0, 2] / next est reward: -4.034801006317139
# Ep 3850 | current sol: [8, 0, 2, 5] / next est reward: -4.123072147369385
# Ep 3850 | current sol: [8, 0, 2, 5, 6, 3, 9] / next est reward: -1.900155782699585
# Ep 3850 | current sol: [8, 0, 2, 5, 6, 3, 9, 7, 1] / next est reward: -1.8250412940979004
# Ep 3850. Loss = 0.182 / median length = 4.302 / last = 6.2084 / epsilon = 0.1000 / lr = 0.0026
# Ep 3860. Loss = 0.214 / median length = 4.323 / last = 3.4163 / epsilon = 0.1000 / lr = 0.0026
# Ep 3870. Loss = 0.189 / median length = 4.281 / last = 3.0190 / epsilon = 0.1000 / lr = 0.0026
# Ep 3880. Loss = 0.182 / median length = 4.281 / last = 5.4410 / epsilon = 0.1000 / lr = 0.0026
# Ep 3890. Loss = 0.165 / median length = 4.518 / last = 4.5568 / epsilon = 0.1000 / lr = 0.0026
# Ep 3900 | current sol: [6] / next est reward: -4.494706153869629
# Ep 3900 | current sol: [6, 0] / next est reward: -4.59648323059082
# Ep 3900 | current sol: [6, 0, 4] / next est reward: -4.812618255615234
# Ep 3900 | current sol: [6, 0, 4, 2] / next est reward: -5.048125267028809
# Ep 3900 | current sol: [6, 0, 4, 2, 1] / next est reward: -5.320487022399902
# Ep 3900 | current sol: [6, 0, 4, 2, 1, 3] / next est reward: -4.986575603485107
# Ep 3900 | current sol: [6, 0, 4, 2, 1, 3, 8] / next est reward: -4.223703384399414
# Ep 3900 | current sol: [6, 0, 4, 2, 1, 3, 8, 7] / next est reward: -3.257713556289673
# Ep 3900 | current sol: [6, 0, 4, 2, 1, 3, 8, 7, 5] / next est reward: -2.188518762588501
# Ep 3900. Loss = 0.069 / median length = 4.442 / last = 3.1064 / epsilon = 0.1000 / lr = 0.0026
# Ep 3910. Loss = 0.129 / median length = 4.514 / last = 3.8353 / epsilon = 0.1000 / lr = 0.0026
# Ep 3920. Loss = 0.125 / median length = 4.606 / last = 3.2667 / epsilon = 0.1000 / lr = 0.0026
# Ep 3930. Loss = 0.185 / median length = 4.596 / last = 3.4682 / epsilon = 0.1000 / lr = 0.0026
# Ep 3940. Loss = 0.133 / median length = 4.518 / last = 3.2391 / epsilon = 0.1000 / lr = 0.0026
# Ep 3950 | current sol: [5] / next est reward: -3.971996307373047
# Ep 3950 | current sol: [5, 0] / next est reward: -4.0182671546936035
# Ep 3950 | current sol: [5, 0, 2, 4] / next est reward: -4.069339752197266
# Ep 3950 | current sol: [5, 0, 2, 4, 8] / next est reward: -4.569769382476807
# Ep 3950 | current sol: [5, 0, 2, 4, 8, 9] / next est reward: -4.223564147949219
# Ep 3950 | current sol: [5, 0, 2, 4, 8, 9, 1] / next est reward: -3.3786978721618652
# Ep 3950 | current sol: [5, 0, 2, 4, 8, 9, 1, 3] / next est reward: -2.507845878601074
# Ep 3950 | current sol: [5, 0, 2, 4, 8, 9, 1, 3, 7] / next est reward: -2.4827356338500977
# Ep 3950. Loss = 0.058 / median length = 4.518 / last = 3.7506 / epsilon = 0.1000 / lr = 0.0026
# Ep 3960. Loss = 0.102 / median length = 4.443 / last = 5.4271 / epsilon = 0.1000 / lr = 0.0026
# Ep 3970. Loss = 0.062 / median length = 4.251 / last = 2.9183 / epsilon = 0.1000 / lr = 0.0025
# Ep 3980. Loss = 0.145 / median length = 4.443 / last = 3.9673 / epsilon = 0.1000 / lr = 0.0025
# Ep 3990. Loss = 0.098 / median length = 4.402 / last = 2.6376 / epsilon = 0.1000 / lr = 0.0025
# Ep 4000 | current sol: [8] / next est reward: -4.284421920776367
# Ep 4000 | current sol: [8, 2] / next est reward: -4.340959072113037
# Ep 4000 | current sol: [8, 2, 0] / next est reward: -4.428518295288086
# Ep 4000 | current sol: [8, 2, 0, 7] / next est reward: -4.609516620635986
# Ep 4000 | current sol: [8, 2, 0, 7, 4] / next est reward: -4.624966621398926
# Ep 4000 | current sol: [8, 2, 0, 7, 4, 5] / next est reward: -4.810988903045654
# Ep 4000 | current sol: [8, 2, 0, 7, 4, 5, 6] / next est reward: -4.660104274749756
# Ep 4000 | current sol: [8, 2, 0, 7, 4, 5, 6, 3] / next est reward: -3.609724283218384
# Ep 4000 | current sol: [8, 2, 0, 7, 4, 5, 6, 3, 9] / next est reward: -2.368126630783081
# Ep 4000. Loss = 0.104 / median length = 4.344 / last = 3.5468 / epsilon = 0.1000 / lr = 0.0025

# %% [markdown]
# ## Inspect Training Metrics
# Let's look at the (moving averages of) loss and path length over training.

# %%
def _moving_avg(x, N=10):
    return np.convolve(np.array(x), np.ones((N,))/N, mode='valid')

plt.figure(figsize=(8,5))
plt.semilogy(_moving_avg(losses, 100))
plt.ylabel('loss')
plt.xlabel('training iteration')

plt.figure(figsize=(8,5))
plt.plot(_moving_avg(path_lengths, 100))
plt.ylabel('average length')
plt.xlabel('episode')
# Out:
# Text(0.5, 0, 'episode')

# %% [markdown]
# ## Re-run Best Model and Look at Paths

# %%
""" Get file with smallest distance
"""
all_lengths_fnames = [f for f in os.listdir(FOLDER_NAME) if f.endswith('.tar')]
shortest_fname = sorted(all_lengths_fnames, key=lambda s: float(s.split('.tar')[0].split('_')[-1]))[0]
print('shortest avg length found: {}'.format(shortest_fname.split('.tar')[0].split('_')[-1]))

""" Load checkpoint
"""
Q_func, Q_net, optimizer, lr_scheduler = init_model(os.path.join(FOLDER_NAME, shortest_fname))

""" A function to plot solutions
"""
def plot_solution(coords, mat, solution):
    plt.scatter(coords[:,0], coords[:,1])
    n = len(coords)
    
    for idx in range(n-1):
        i, next_i = solution[idx], solution[idx+1]
        plt.plot([coords[i, 0], coords[next_i, 0]], [coords[i, 1], coords[next_i, 1]], 'k', lw=2, alpha=0.8)
    
    i, next_i = solution[-1], solution[0]
    plt.plot([coords[i, 0], coords[next_i, 0]], [coords[i, 1], coords[next_i, 1]], 'k', lw=2, alpha=0.8)
    plt.plot(coords[solution[0], 0], coords[solution[0], 1], 'x', markersize=10)


    
""" Generate example solutions
"""
NR_NODES = 10
for sample in range(30):
    coords, W_np = get_graph_mat(n=NR_NODES)
    W = torch.tensor(W_np, dtype=torch.float32, requires_grad=False, device=device)
    
    solution = [random.randint(0, NR_NODES-1)]
    current_state = State(partial_solution=solution, W=W, coords=coords)
    current_state_tsr = state2tens(current_state)
    
    while not is_state_final(current_state):
        next_node, est_reward = Q_func.get_best_action(current_state_tsr, 
                                                       current_state)
        
        
        solution = solution + [next_node]
        current_state = State(partial_solution=solution, W=W, coords=coords)
        current_state_tsr = state2tens(current_state)
        
    plt.figure()
    plot_solution(coords, W, solution)
    plt.title('model / len = {}'.format(total_distance(solution, W)))
    
    # for comparison, plot a random solution
    plt.figure()
    random_solution = list(range(NR_NODES))
    plot_solution(coords, W, random_solution)
    plt.title('random / len = {}'.format(total_distance(random_solution, W)))
# Out:
# shortest avg length found: 4.166822470724583
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:52: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
